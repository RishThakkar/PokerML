# %%
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import numpy as np
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
# Out:
# 2024-03-21 22:41:06.966708: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
source_dir  = "NewDatasetAugmentedv4"
destination_dir  = "PokerDataset"

# %%
# Create the destination directory if it doesn't exist
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

# Iterate through the images in the source directory
for filename in os.listdir(source_dir):
    # Extract the label from the image filename
    label = filename.split('.')[0]  # Assumes label is before the first period
    
    # Create the label directory if it doesn't exist
    label_dir = os.path.join(destination_dir, label)
    if not os.path.exists(label_dir):
        os.makedirs(label_dir)
    
    # Define the source and destination paths
    source_path = os.path.join(source_dir, filename)
    destination_path = os.path.join(label_dir, filename)
    
    # Move the image to the appropriate label directory
    shutil.move(source_path, destination_path)

print("Directory structure conversion complete.")
# Out:
# Directory structure conversion complete.

# %%
DATA_DIR = "PokerDataset"  
IMAGE_WIDTH = 64
IMAGE_HEIGHT = 64
TEST_SIZE = 0.2
NUM_CLASSES = 52

# %%
image_paths = []
labels = []

# %%
for label in os.listdir(DATA_DIR):
    label_dir = os.path.join(DATA_DIR, label)
    for image_file in os.listdir(label_dir):
        image_paths.append(os.path.join(label_dir, image_file))
        labels.append(label)

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(
    image_paths, labels, test_size=TEST_SIZE, random_state=42, stratify=labels)

# %%
# Encode labels
label_encoder = LabelEncoder()
label_encoder.fit(y_train_val)
y_train_val_encoded = label_encoder.transform(y_train_val)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Convert integer labels to categorical format
y_train_val = to_categorical(y_train_val_encoded, NUM_CLASSES)

# Convert integer labels to categorical format
y_test = to_categorical(y_test_encoded, NUM_CLASSES)

# %%
# Verify one-hot encoding
print("Shape of y_train_val:", y_train_val.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of y_train_val: (624, 52)
# Shape of y_test: (156, 52)

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))
    img_array = img_to_array(img) / 255.0  # Normalize pixel values
    return img_array

# %%
X_train_val = [preprocess_image(image_path) for image_path in X_train_val]
X_test = [preprocess_image(image_path) for image_path in X_test]

# %%
X_train_val = np.array(X_train_val)
X_test = np.array(X_test)

# %%
# Save the preprocessed data
np.save('X_train_val.npy', X_train_val)
np.save('X_test.npy', X_test)
np.save('y_train_val.npy', y_train_val)
np.save('y_test.npy', y_test)
np.save('classes.npy', label_encoder.classes_)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from tensorflow.keras.regularizers import l1
from callbacks import all_callbacks

# %%
model = Sequential()
model.add(Conv2D(4, (3, 3), activation='relu', input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3), name='conv1'))
model.add(MaxPooling2D(pool_size=(2, 2), name='maxpool1'))
model.add(Conv2D(8, (3, 3), activation='relu', name='conv2'))
model.add(MaxPooling2D(pool_size=(2, 2), name='maxpool2'))
model.add(Flatten(name='flatten'))
model.add(Dense(32, activation='relu', name='dense1'))
model.add(Dense(NUM_CLASSES, activation='softmax', name='output'))
# Out:
# 2024-03-21 22:41:10.431332: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print("Model summary:")
model.summary()
# Out:
# Model summary:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 62, 62, 4)         112
#
#  maxpool1 (MaxPooling2D)     (None, 31, 31, 4)         0
#
#  conv2 (Conv2D)              (None, 29, 29, 8)         296
#
#  maxpool2 (MaxPooling2D)     (None, 14, 14, 8)         0
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense1 (Dense)              (None, 32)                50208
#
#  output (Dense)              (None, 52)                1716
#
# =================================================================
# Total params: 52,332
# Trainable params: 52,332
# Non-trainable params: 0
# _________________________________________________________________

# %%
train = True
if train:
    adam = Adam(lr=0.01)
    model.compile(optimizer=adam, loss=['categorical_crossentropy'], metrics=['accuracy'])
    callbacks = all_callbacks(
        stop_patience=1000,
        lr_factor=0.5,
        lr_patience=10,
        lr_epsilon=0.000001,
        lr_cooldown=2,
        lr_minimum=0.0000001,
        outputDir='model_1',
    )
    model.fit(
        X_train_val,
        y_train_val,
        batch_size=10,
        epochs=50,
        validation_split=0.25,
        shuffle=True,
        callbacks=callbacks.callbacks,
    )
else:
    from tensorflow.keras.models import load_model

    model = load_model('model_1/KERAS_check_best_model.h5')
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 43/47 [==========================>...] - ETA: 0s - loss: 3.9967 - accuracy: 0.0116
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 1: val_loss improved from inf to 3.95554, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 1: val_loss improved from inf to 3.95554, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 1: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 1: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 2s 21ms/step - loss: 3.9932 - accuracy: 0.0107 - val_loss: 3.9555 - val_accuracy: 0.0128 - lr: 0.0010
# Epoch 2/50
# 47/47 [==============================] - ETA: 0s - loss: 3.9487 - accuracy: 0.0256
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 2: val_loss did not improve from 3.95554
#
# Epoch 2: val_loss did not improve from 3.95554
#
# Epoch 2: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 2: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 13ms/step - loss: 3.9487 - accuracy: 0.0256 - val_loss: 3.9582 - val_accuracy: 0.0128 - lr: 0.0010
# Epoch 3/50
# 47/47 [==============================] - ETA: 0s - loss: 3.9437 - accuracy: 0.0214
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 3: val_loss did not improve from 3.95554
#
# Epoch 3: val_loss did not improve from 3.95554
#
# Epoch 3: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 3: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 3.9437 - accuracy: 0.0214 - val_loss: 3.9632 - val_accuracy: 0.0128 - lr: 0.0010
# Epoch 4/50
# 45/47 [===========================>..] - ETA: 0s - loss: 3.9398 - accuracy: 0.0222
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 4: val_loss did not improve from 3.95554
#
# Epoch 4: val_loss did not improve from 3.95554
#
# Epoch 4: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 4: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 3.9397 - accuracy: 0.0214 - val_loss: 3.9576 - val_accuracy: 0.0128 - lr: 0.0010
# Epoch 5/50
# 46/47 [============================>.] - ETA: 0s - loss: 3.9288 - accuracy: 0.0283
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 5: val_loss improved from 3.95554 to 3.95140, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 5: val_loss improved from 3.95554 to 3.95140, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 5: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 5: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 3.9304 - accuracy: 0.0278 - val_loss: 3.9514 - val_accuracy: 0.0192 - lr: 0.0010
# Epoch 6/50
# 46/47 [============================>.] - ETA: 0s - loss: 3.8876 - accuracy: 0.0457
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 6: val_loss improved from 3.95140 to 3.91511, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 6: val_loss improved from 3.95140 to 3.91511, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 6: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 6: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 3.8867 - accuracy: 0.0470 - val_loss: 3.9151 - val_accuracy: 0.0064 - lr: 0.0010
# Epoch 7/50
# 46/47 [============================>.] - ETA: 0s - loss: 3.8247 - accuracy: 0.0413
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 7: val_loss improved from 3.91511 to 3.85278, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 7: val_loss improved from 3.91511 to 3.85278, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 7: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 7: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 3.8238 - accuracy: 0.0406 - val_loss: 3.8528 - val_accuracy: 0.0192 - lr: 0.0010
# Epoch 8/50
# 45/47 [===========================>..] - ETA: 0s - loss: 3.6765 - accuracy: 0.0733
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 8: val_loss improved from 3.85278 to 3.75619, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 8: val_loss improved from 3.85278 to 3.75619, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 8: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 8: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 3.6899 - accuracy: 0.0705 - val_loss: 3.7562 - val_accuracy: 0.0256 - lr: 0.0010
# Epoch 9/50
# 43/47 [==========================>...] - ETA: 0s - loss: 3.5440 - accuracy: 0.0744
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 9: val_loss improved from 3.75619 to 3.66227, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 9: val_loss improved from 3.75619 to 3.66227, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 9: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 9: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 3.5485 - accuracy: 0.0684 - val_loss: 3.6623 - val_accuracy: 0.0385 - lr: 0.0010
# Epoch 10/50
# 46/47 [============================>.] - ETA: 0s - loss: 3.4184 - accuracy: 0.0913
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 10: val_loss improved from 3.66227 to 3.55807, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 10: val_loss improved from 3.66227 to 3.55807, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 10: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 10: saving model to model_1/KERAS_check_model_last_weights.h5
#
# Epoch 10: saving model to model_1/KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 3.4134 - accuracy: 0.0919 - val_loss: 3.5581 - val_accuracy: 0.0513 - lr: 0.0010
# Epoch 11/50
# 46/47 [============================>.] - ETA: 0s - loss: 3.2037 - accuracy: 0.1522
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 11: val_loss improved from 3.55807 to 3.48827, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 11: val_loss improved from 3.55807 to 3.48827, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 11: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 11: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 3.1984 - accuracy: 0.1538 - val_loss: 3.4883 - val_accuracy: 0.0769 - lr: 0.0010
# Epoch 12/50
# 45/47 [===========================>..] - ETA: 0s - loss: 3.0186 - accuracy: 0.1844
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 12: val_loss improved from 3.48827 to 3.41286, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 12: val_loss improved from 3.48827 to 3.41286, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 12: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 12: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 3.0163 - accuracy: 0.1816 - val_loss: 3.4129 - val_accuracy: 0.0705 - lr: 0.0010
# Epoch 13/50
# 45/47 [===========================>..] - ETA: 0s - loss: 2.8117 - accuracy: 0.2244
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 13: val_loss improved from 3.41286 to 3.30933, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 13: val_loss improved from 3.41286 to 3.30933, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 13: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 13: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 2.8059 - accuracy: 0.2201 - val_loss: 3.3093 - val_accuracy: 0.0833 - lr: 0.0010
# Epoch 14/50
# 43/47 [==========================>...] - ETA: 0s - loss: 2.5779 - accuracy: 0.2721
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 14: val_loss improved from 3.30933 to 3.11439, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 14: val_loss improved from 3.30933 to 3.11439, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 14: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 14: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 2.5821 - accuracy: 0.2756 - val_loss: 3.1144 - val_accuracy: 0.1538 - lr: 0.0010
# Epoch 15/50
# 43/47 [==========================>...] - ETA: 0s - loss: 2.4019 - accuracy: 0.3116
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 15: val_loss improved from 3.11439 to 2.94076, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 15: val_loss improved from 3.11439 to 2.94076, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 15: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 15: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 2.4028 - accuracy: 0.3056 - val_loss: 2.9408 - val_accuracy: 0.1603 - lr: 0.0010
# Epoch 16/50
# 46/47 [============================>.] - ETA: 0s - loss: 2.2520 - accuracy: 0.3283
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 16: val_loss improved from 2.94076 to 2.89349, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 16: val_loss improved from 2.94076 to 2.89349, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 16: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 16: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 2.2548 - accuracy: 0.3269 - val_loss: 2.8935 - val_accuracy: 0.1474 - lr: 0.0010
# Epoch 17/50
# 44/47 [===========================>..] - ETA: 0s - loss: 2.0994 - accuracy: 0.3705
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 17: val_loss improved from 2.89349 to 2.80379, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 17: val_loss improved from 2.89349 to 2.80379, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 17: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 17: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 2.0977 - accuracy: 0.3697 - val_loss: 2.8038 - val_accuracy: 0.1538 - lr: 0.0010
# Epoch 18/50
# 45/47 [===========================>..] - ETA: 0s - loss: 1.9034 - accuracy: 0.4133
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 18: val_loss improved from 2.80379 to 2.64938, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 18: val_loss improved from 2.80379 to 2.64938, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 18: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 18: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 1.9268 - accuracy: 0.4081 - val_loss: 2.6494 - val_accuracy: 0.2115 - lr: 0.0010
# Epoch 19/50
# 43/47 [==========================>...] - ETA: 0s - loss: 1.7811 - accuracy: 0.4465
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 19: val_loss improved from 2.64938 to 2.61888, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 19: val_loss improved from 2.64938 to 2.61888, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 19: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 19: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 1.7966 - accuracy: 0.4402 - val_loss: 2.6189 - val_accuracy: 0.1987 - lr: 0.0010
# Epoch 20/50
# 47/47 [==============================] - ETA: 0s - loss: 1.6916 - accuracy: 0.4722
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 20: val_loss improved from 2.61888 to 2.49194, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 20: val_loss improved from 2.61888 to 2.49194, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 20: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 20: saving model to model_1/KERAS_check_model_last_weights.h5
#
# Epoch 20: saving model to model_1/KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 1.6916 - accuracy: 0.4722 - val_loss: 2.4919 - val_accuracy: 0.2051 - lr: 0.0010
# Epoch 21/50
# 43/47 [==========================>...] - ETA: 0s - loss: 1.5456 - accuracy: 0.5163
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 21: val_loss improved from 2.49194 to 2.46274, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 21: val_loss improved from 2.49194 to 2.46274, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 21: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 21: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 1.5469 - accuracy: 0.5214 - val_loss: 2.4627 - val_accuracy: 0.2756 - lr: 0.0010
# Epoch 22/50
# 42/47 [=========================>....] - ETA: 0s - loss: 1.4568 - accuracy: 0.5524
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 22: val_loss improved from 2.46274 to 2.39920, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 22: val_loss improved from 2.46274 to 2.39920, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 22: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 22: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 1.4473 - accuracy: 0.5513 - val_loss: 2.3992 - val_accuracy: 0.2564 - lr: 0.0010
# Epoch 23/50
# 46/47 [============================>.] - ETA: 0s - loss: 1.3833 - accuracy: 0.5739
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 23: val_loss improved from 2.39920 to 2.39602, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 23: val_loss improved from 2.39920 to 2.39602, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 23: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 23: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 1.3810 - accuracy: 0.5726 - val_loss: 2.3960 - val_accuracy: 0.2564 - lr: 0.0010
# Epoch 24/50
# 43/47 [==========================>...] - ETA: 0s - loss: 1.2971 - accuracy: 0.6023
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 24: val_loss did not improve from 2.39602
#
# Epoch 24: val_loss did not improve from 2.39602
#
# Epoch 24: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 24: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 13ms/step - loss: 1.2937 - accuracy: 0.6026 - val_loss: 2.4770 - val_accuracy: 0.2821 - lr: 0.0010
# Epoch 25/50
# 42/47 [=========================>....] - ETA: 0s - loss: 1.2308 - accuracy: 0.6024
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 25: val_loss improved from 2.39602 to 2.35425, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 25: val_loss improved from 2.39602 to 2.35425, saving model to model_1/KERAS_check_best_model_weights.h5
#
# Epoch 25: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 25: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 1.2266 - accuracy: 0.6047 - val_loss: 2.3543 - val_accuracy: 0.2949 - lr: 0.0010
# Epoch 26/50
# 42/47 [=========================>....] - ETA: 0s - loss: 1.1315 - accuracy: 0.6476
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 26: val_loss improved from 2.35425 to 2.27227, saving model to model_1/KERAS_check_best_model.h5
#
# Epoch 26: val_loss improved from 2.35425 to 2.27227, saving model to model_1/KERAS_check_best_model_weights.h5
# Epoch 26: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 26: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 1.1695 - accuracy: 0.6325 - val_loss: 2.2723 - val_accuracy: 0.3846 - lr: 0.0010
# Epoch 27/50
# 46/47 [============================>.] - ETA: 0s - loss: 1.0846 - accuracy: 0.6565
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 27: val_loss did not improve from 2.27227
#
# Epoch 27: val_loss did not improve from 2.27227
#
# Epoch 27: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 27: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 1.0912 - accuracy: 0.6560 - val_loss: 2.5973 - val_accuracy: 0.3077 - lr: 0.0010
# Epoch 28/50
# 45/47 [===========================>..] - ETA: 0s - loss: 1.0659 - accuracy: 0.6533
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 28: val_loss did not improve from 2.27227
#
# Epoch 28: val_loss did not improve from 2.27227
#
# Epoch 28: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 28: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 13ms/step - loss: 1.0763 - accuracy: 0.6453 - val_loss: 2.5113 - val_accuracy: 0.3269 - lr: 0.0010
# Epoch 29/50
# 47/47 [==============================] - ETA: 0s - loss: 0.9673 - accuracy: 0.7179
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 29: val_loss did not improve from 2.27227
#
# Epoch 29: val_loss did not improve from 2.27227
#
# Epoch 29: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 29: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.9673 - accuracy: 0.7179 - val_loss: 2.3474 - val_accuracy: 0.3846 - lr: 0.0010
# Epoch 30/50
# 43/47 [==========================>...] - ETA: 0s - loss: 0.8985 - accuracy: 0.7209
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 30: val_loss did not improve from 2.27227
#
# Epoch 30: val_loss did not improve from 2.27227
#
# Epoch 30: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 30: saving model to model_1/KERAS_check_model_last_weights.h5
#
# Epoch 30: saving model to model_1/KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 0.9048 - accuracy: 0.7244 - val_loss: 2.4485 - val_accuracy: 0.3718 - lr: 0.0010
# Epoch 31/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.8536 - accuracy: 0.7348
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 31: val_loss did not improve from 2.27227
#
# Epoch 31: val_loss did not improve from 2.27227
#
# Epoch 31: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 31: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.8547 - accuracy: 0.7350 - val_loss: 2.4248 - val_accuracy: 0.4231 - lr: 0.0010
# Epoch 32/50
# 42/47 [=========================>....] - ETA: 0s - loss: 0.7713 - accuracy: 0.7857
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 32: val_loss did not improve from 2.27227
#
# Epoch 32: val_loss did not improve from 2.27227
#
# Epoch 32: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 32: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.7786 - accuracy: 0.7756 - val_loss: 2.4063 - val_accuracy: 0.4359 - lr: 0.0010
# Epoch 33/50
# 43/47 [==========================>...] - ETA: 0s - loss: 0.7607 - accuracy: 0.7814
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 33: val_loss did not improve from 2.27227
#
# Epoch 33: val_loss did not improve from 2.27227
#
# Epoch 33: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 33: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 13ms/step - loss: 0.7468 - accuracy: 0.7842 - val_loss: 2.3939 - val_accuracy: 0.4423 - lr: 0.0010
# Epoch 34/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.7080 - accuracy: 0.7891
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 34: val_loss did not improve from 2.27227
#
# Epoch 34: val_loss did not improve from 2.27227
#
# Epoch 34: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 34: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 0.7089 - accuracy: 0.7885 - val_loss: 2.4491 - val_accuracy: 0.4487 - lr: 0.0010
# Epoch 35/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.6561 - accuracy: 0.8065
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 35: val_loss did not improve from 2.27227
#
# Epoch 35: val_loss did not improve from 2.27227
#
# Epoch 35: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 35: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.6630 - accuracy: 0.8034 - val_loss: 2.4082 - val_accuracy: 0.4231 - lr: 0.0010
# Epoch 36/50
# 42/47 [=========================>....] - ETA: 0s - loss: 0.6213 - accuracy: 0.8238
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 36: val_loss did not improve from 2.27227
#
# Epoch 36: val_loss did not improve from 2.27227
#
# Epoch 36: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 36: saving model to model_1/KERAS_check_model_last_weights.h5
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 0.6224 - accuracy: 0.8248 - val_loss: 2.3985 - val_accuracy: 0.4679 - lr: 0.0010
# Epoch 37/50
# 47/47 [==============================] - ETA: 0s - loss: 0.5285 - accuracy: 0.8440
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 37: val_loss did not improve from 2.27227
#
# Epoch 37: val_loss did not improve from 2.27227
#
# Epoch 37: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 37: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 13ms/step - loss: 0.5285 - accuracy: 0.8440 - val_loss: 2.4896 - val_accuracy: 0.4808 - lr: 5.0000e-04
# Epoch 38/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.4992 - accuracy: 0.8956
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 38: val_loss did not improve from 2.27227
#
# Epoch 38: val_loss did not improve from 2.27227
#
# Epoch 38: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 38: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.4897 - accuracy: 0.8996 - val_loss: 2.4489 - val_accuracy: 0.5000 - lr: 5.0000e-04
# Epoch 39/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.4731 - accuracy: 0.9000
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 39: val_loss did not improve from 2.27227
#
# Epoch 39: val_loss did not improve from 2.27227
#
# Epoch 39: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 39: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 0.4731 - accuracy: 0.8996 - val_loss: 2.4725 - val_accuracy: 0.5064 - lr: 5.0000e-04
# Epoch 40/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.4594 - accuracy: 0.9087
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 40: val_loss did not improve from 2.27227
#
# Epoch 40: val_loss did not improve from 2.27227
#
# Epoch 40: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 40: saving model to model_1/KERAS_check_model_last_weights.h5
#
# Epoch 40: saving model to model_1/KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 0.4577 - accuracy: 0.9103 - val_loss: 2.4184 - val_accuracy: 0.4744 - lr: 5.0000e-04
# Epoch 41/50
# 42/47 [=========================>....] - ETA: 0s - loss: 0.4477 - accuracy: 0.9024
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 41: val_loss did not improve from 2.27227
# Epoch 41: val_loss did not improve from 2.27227
#
# Epoch 41: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 41: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 0.4445 - accuracy: 0.9038 - val_loss: 2.4683 - val_accuracy: 0.5128 - lr: 5.0000e-04
# Epoch 42/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.4263 - accuracy: 0.9065
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 42: val_loss did not improve from 2.27227
#
# Epoch 42: val_loss did not improve from 2.27227
#
# Epoch 42: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 42: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 0.4257 - accuracy: 0.9081 - val_loss: 2.4217 - val_accuracy: 0.5064 - lr: 5.0000e-04
# Epoch 43/50
# 47/47 [==============================] - ETA: 0s - loss: 0.4065 - accuracy: 0.9274
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 43: val_loss did not improve from 2.27227
#
# Epoch 43: val_loss did not improve from 2.27227
#
# Epoch 43: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 43: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 0.4065 - accuracy: 0.9274 - val_loss: 2.4538 - val_accuracy: 0.5256 - lr: 5.0000e-04
# Epoch 44/50
# 47/47 [==============================] - ETA: 0s - loss: 0.3857 - accuracy: 0.9274
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 44: val_loss did not improve from 2.27227
#
# Epoch 44: val_loss did not improve from 2.27227
#
# Epoch 44: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 44: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 0.3857 - accuracy: 0.9274 - val_loss: 2.5564 - val_accuracy: 0.5128 - lr: 5.0000e-04
# Epoch 45/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.3778 - accuracy: 0.9239
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 45: val_loss did not improve from 2.27227
#
# Epoch 45: val_loss did not improve from 2.27227
#
# Epoch 45: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 45: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 0.3813 - accuracy: 0.9231 - val_loss: 2.6067 - val_accuracy: 0.4936 - lr: 5.0000e-04
# Epoch 46/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.3573 - accuracy: 0.9326
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 46: val_loss did not improve from 2.27227
#
# Epoch 46: val_loss did not improve from 2.27227
#
# Epoch 46: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 46: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 13ms/step - loss: 0.3643 - accuracy: 0.9295 - val_loss: 2.6166 - val_accuracy: 0.5000 - lr: 5.0000e-04
# Epoch 47/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.3496 - accuracy: 0.9326
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 47: val_loss did not improve from 2.27227
#
# Epoch 47: val_loss did not improve from 2.27227
#
# Epoch 47: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 47: saving model to model_1/KERAS_check_model_last_weights.h5
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 18ms/step - loss: 0.3471 - accuracy: 0.9338 - val_loss: 2.5089 - val_accuracy: 0.4872 - lr: 5.0000e-04
# Epoch 48/50
# 43/47 [==========================>...] - ETA: 0s - loss: 0.3315 - accuracy: 0.9512
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 48: val_loss did not improve from 2.27227
#
# Epoch 48: val_loss did not improve from 2.27227
#
# Epoch 48: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 48: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 13ms/step - loss: 0.3253 - accuracy: 0.9530 - val_loss: 2.5958 - val_accuracy: 0.5128 - lr: 2.5000e-04
# Epoch 49/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.3059 - accuracy: 0.9578
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 49: val_loss did not improve from 2.27227
#
# Epoch 49: val_loss did not improve from 2.27227
#
# Epoch 49: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 49: saving model to model_1/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 13ms/step - loss: 0.3093 - accuracy: 0.9551 - val_loss: 2.6447 - val_accuracy: 0.5064 - lr: 2.5000e-04
# Epoch 50/50
# 43/47 [==========================>...] - ETA: 0s - loss: 0.3051 - accuracy: 0.9535
# ***callbacks***
# saving losses to model_1/losses.log
#
# Epoch 50: val_loss did not improve from 2.27227
#
# Epoch 50: val_loss did not improve from 2.27227
#
# Epoch 50: saving model to model_1/KERAS_check_model_last.h5
#
# Epoch 50: saving model to model_1/KERAS_check_model_last_weights.h5
#
# Epoch 50: saving model to model_1/KERAS_check_model_epoch50.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 14ms/step - loss: 0.3066 - accuracy: 0.9530 - val_loss: 2.6129 - val_accuracy: 0.5192 - lr: 2.5000e-04

# %%
import plotting
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

y_keras = model.predict(X_test)
print("Accuracy: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_keras, axis=1))))
plt.figure(figsize=(9, 9))
_ = plotting.makeRoc(y_test, y_keras, label_encoder.classes_)
# Out:
# 5/5 [==============================] - 0s 9ms/step
# Accuracy: 0.5064102564102564
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]

# %%
import hls4ml
import plotting

config = hls4ml.utils.config_from_keras_model(model, granularity='model')
print("-----------------------------------")
print("Configuration")
plotting.print_dict(config)
print("-----------------------------------")
hls_model = hls4ml.converters.convert_from_keras_model(
    model, hls_config=config, output_dir='model_1/hls4ml_prj', part='xcu250-figd2104-2L-e'
)
# Out:
# /home/esp2024/rht2122/miniconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/hls4ml/converters/__init__.py:27: UserWarning: WARNING: Pytorch converter is not enabled!
#   warnings.warn("WARNING: Pytorch converter is not enabled!", stacklevel=1)
# WARNING: Failed to import handlers from pooling.py: No module named 'torch'.
# WARNING: Failed to import handlers from core.py: No module named 'torch'.
# WARNING: Failed to import handlers from convolution.py: No module named 'torch'.
# WARNING: Failed to import handlers from reshape.py: No module named 'torch'.
# WARNING: Failed to import handlers from merge.py: No module named 'torch'.
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# -----------------------------------
# Configuration
# Model
#   Precision:         fixed<16,6>
#   ReuseFactor:       1
#   Strategy:          Latency
#   BramFactor:        1000000000
#   TraceOutput:       False
# -----------------------------------
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# Creating HLS model
# WARNING: Layer conv1 requires "dataflow" pipeline style. Switching to "dataflow" pipeline style.

# %%
hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True, to_file=None)

# %%
hls_model.compile()
X_test = np.ascontiguousarray(X_test)
y_hls = hls_model.predict(X_test)
# Out:
# Writing HLS project
# Done

# %%
print("Keras  Accuracy: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_keras, axis=1))))
print("hls4ml Accuracy: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_hls, axis=1))))

fig, ax = plt.subplots(figsize=(9, 9))
_ = plotting.makeRoc(y_test, y_keras, label_encoder.classes_)
plt.gca().set_prop_cycle(None)  # reset the colors
_ = plotting.makeRoc(y_test, y_hls, label_encoder.classes_, linestyle='--')

from matplotlib.lines import Line2D

lines = [Line2D([0], [0], ls='-'), Line2D([0], [0], ls='--')]
from matplotlib.legend import Legend

leg = Legend(ax, lines, labels=['keras', 'hls4ml'], loc='lower right', frameon=False)
ax.add_artist(leg)
# Out:
# Keras  Accuracy: 0.5064102564102564
# hls4ml Accuracy: 0.03205128205128205
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]

# %% [markdown]
# Part 2

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
import plotting
import os

# %%
X_train_val = np.load('X_train_val.npy')
X_test = np.ascontiguousarray(np.load('X_test.npy'))
y_train_val = np.load('y_train_val.npy')
y_test = np.load('y_test.npy', allow_pickle=True)
classes = np.load('classes.npy', allow_pickle=True)

# %%
from tensorflow.keras.models import load_model

model = load_model('model_1/KERAS_check_best_model.h5')
y_keras = model.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 10ms/step

# %%
import hls4ml

config = hls4ml.utils.config_from_keras_model(model, granularity='name')
print("-----------------------------------")
plotting.print_dict(config)
print("-----------------------------------")
# Out:
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# -----------------------------------
# Model
#   Precision:         fixed<16,6>
#   ReuseFactor:       1
#   Strategy:          Latency
#   BramFactor:        1000000000
#   TraceOutput:       False
# LayerName
#   conv1_input
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   conv1
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#       weight:        fixed<16,6>
#       bias:          fixed<16,6>
#   conv1_relu
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   maxpool1
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   conv2
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#       weight:        fixed<16,6>
#       bias:          fixed<16,6>
#   conv2_relu
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   maxpool2
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   flatten
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   dense1
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#       weight:        fixed<16,6>
#       bias:          fixed<16,6>
#   dense1_relu
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   output
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#       weight:        fixed<16,6>
#       bias:          fixed<16,6>
#   output_softmax
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
# -----------------------------------

# %%
# %matplotlib inline
for layer in config['LayerName'].keys():
    config['LayerName'][layer]['Trace'] = True
hls_model = hls4ml.converters.convert_from_keras_model(
    model, hls_config=config, output_dir='model_1/hls4ml_prj_2', part='xcu250-figd2104-2L-e'
)
hls4ml.model.profiling.numerical(model=model, hls_model=hls_model, X=X_test[:1000])
# Out:
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# Creating HLS model
# WARNING: Layer conv1 requires "dataflow" pipeline style. Switching to "dataflow" pipeline style.
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# Creating HLS model
# WARNING: Layer conv1 requires "dataflow" pipeline style. Switching to "dataflow" pipeline style.
# Profiling weights (before optimization)
# Profiling weights (final / after optimization)
# Profiling activations (before optimization)
# 5/5 [==============================] - 0s 10ms/step
#    conv1
#    maxpool1
#    conv2
#    maxpool2
#    flatten
#    dense1
#    output
# Profiling activations (final / after optimization)
# Recompiling myproject with tracing
# Writing HLS project
# Done
#    conv1
#    conv1_relu
#    maxpool1
#    conv2
#    conv2_relu
#    maxpool2
#    dense1
#    dense1_relu
#    output
#    output_softmax
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %%
config['LayerName']['conv1']['Precision']['weight'] = 'ap_fixed<8,2>'
hls_model = hls4ml.converters.convert_from_keras_model(
    model, hls_config=config, output_dir='model_1/hls4ml_prj_2', part='xcu250-figd2104-2L-e'
)
hls4ml.model.profiling.numerical(model=model, hls_model=hls_model)
hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True, to_file=None)
# Out:
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# Creating HLS model
# WARNING: Layer conv1 requires "dataflow" pipeline style. Switching to "dataflow" pipeline style.
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# Creating HLS model
# WARNING: Layer conv1 requires "dataflow" pipeline style. Switching to "dataflow" pipeline style.
# Profiling weights (before optimization)
# Profiling weights (final / after optimization)

# %%
for layer in config['LayerName'].keys():
    config['LayerName'][layer]['Trace'] = True
hls_model = hls4ml.converters.convert_from_keras_model(
    model, hls_config=config, output_dir='model_1/hls4ml_prj_2', part='xcu250-figd2104-2L-e'
)
# Out:
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# Creating HLS model
# WARNING: Layer conv1 requires "dataflow" pipeline style. Switching to "dataflow" pipeline style.

# %%
hls_model.compile()
hls4ml_pred, hls4ml_trace = hls_model.trace(X_test[:1000])
keras_trace = hls4ml.model.profiling.get_ymodel_keras(model, X_test[:1000])
y_hls = hls_model.predict(X_test)
# Out:
# Writing HLS project
# Done
# Recompiling myproject with tracing
# Writing HLS project
# Done
# 5/5 [==============================] - 0s 10ms/step
# 5/5 [==============================] - 0s 10ms/step
# 5/5 [==============================] - 0s 11ms/step
# 5/5 [==============================] - 0s 11ms/step
# 5/5 [==============================] - 0s 12ms/step
# Done taking outputs for Keras model.

# %%
print("Keras layer 'conv1', first sample:")
print(keras_trace['conv1'][0])
print("hls4ml layer 'conv1', first sample:")
print(hls4ml_trace['conv1'][0])
# Out:
# Keras layer 'conv1', first sample:
# [[[-0.10090087  2.230112   -0.14103182  0.00906195]
#   [-0.14471416  2.408958    0.11557019 -0.14474492]
#   [-0.10235672  2.4514916   0.20767175 -0.2148019 ]
#   ...
#   [-0.16173641  2.394158   -0.02635722 -0.04954152]
#   [-0.21398585  2.2913141   0.00894792 -0.16937336]
#   [-0.67454225  2.483252   -0.2816822   0.48855847]]
#
#  [[-0.0449671   2.3920858   0.13339442 -0.20740779]
#   [-0.13067316  2.3362575  -0.06479864 -0.07717471]
#   [-0.15974046  2.3239577  -0.04627188 -0.07654737]
#   ...
#   [-0.13125978  2.3388817  -0.06247167 -0.083672  ]
#   [-0.19351856  2.4338417  -0.07933991  0.03285004]
#   [-0.35041124  2.6988974   0.07420827  0.21724693]]
#
#  [[-0.11279903  2.3347447  -0.01601896 -0.12768862]
#   [-0.21027665  2.2554677  -0.03802523 -0.04319119]
#   [-0.5856412   1.7558756  -0.02877113  0.00922006]
#   ...
#   [-0.13125978  2.3388817  -0.06247167 -0.083672  ]
#   [-0.13125978  2.3388817  -0.06247167 -0.083672  ]
#   [-0.13125978  2.3388817  -0.06247167 -0.083672  ]]
#
#  ...
#
#  [[ 0.07040249  2.1863084  -0.04370165 -0.19974966]
#   [-0.1287357   2.3311913  -0.06609945 -0.08269681]
#   [-0.13125978  2.3388817  -0.06247167 -0.083672  ]
#   ...
#   [ 0.03023155  2.3735986   0.2095008  -0.36558914]
#   [-0.3060056   2.2317212  -0.07500106 -0.09627005]
#   [-0.08253746  2.1865253  -0.10096009  0.01255508]]
#
#  [[ 0.16771051  2.0338032   0.1143829  -0.19781391]
#   [-0.01526827  2.1760702  -0.26641703 -0.076658  ]
#   [-0.12375312  2.314006   -0.08246621 -0.08227614]
#   ...
#   [-0.250228    2.2552452  -0.08455399 -0.08904032]
#   [-0.11186253  2.1541865  -0.12096651 -0.06727298]
#   [-0.12751664  2.2691462  -0.16506751  0.0839142 ]]
#
#  [[-0.05027117  2.3654807   0.11896202 -0.03915575]
#   [-0.20659994  2.0399091  -0.17853282 -0.05173017]
#   [-0.01355088  2.1514087  -0.0815856  -0.06561179]
#   ...
#   [-0.12259857  2.2322774  -0.18562211 -0.08234519]
#   [-1.0783913   1.7352024  -0.28740084  0.04789799]
#   [-0.2368991   0.65619063 -0.13635843 -0.12477718]]]
# hls4ml layer 'conv1', first sample:
# [[[-0.28320312  2.0126953  -0.34277344 -0.20800781]
#   [-0.3310547   2.1894531  -0.09082031 -0.3671875 ]
#   [-0.29003906  2.2353516   0.00585938 -0.4375    ]
#   ...
#   [-0.34765625  2.1748047  -0.23144531 -0.27539062]
#   [-0.39453125  2.078125   -0.19238281 -0.3935547 ]
#   [-0.8076172   2.3105469  -0.44628906  0.29492188]]
#
#  [[-0.23535156  2.1699219  -0.07128906 -0.4345703 ]
#   [-0.3203125   2.1113281  -0.27539062 -0.30664062]
#   [-0.35058594  2.1015625  -0.25585938 -0.3046875 ]
#   ...
#   [-0.31835938  2.118164   -0.26953125 -0.3095703 ]
#   [-0.37695312  2.2148438  -0.28222656 -0.18945312]
#   [-0.515625    2.4970703  -0.11132812  0.01464844]]
#
#  [[-0.3017578   2.1074219  -0.22753906 -0.36035156]
#   [-0.40039062  2.0322266  -0.24511719 -0.26953125]
#   [-0.7675781   1.5507812  -0.22070312 -0.19726562]
#   ...
#   [-0.31835938  2.118164   -0.26953125 -0.3095703 ]
#   [-0.31835938  2.118164   -0.26953125 -0.3095703 ]
#   [-0.31835938  2.118164   -0.26953125 -0.3095703 ]]
#
#  ...
#
#  [[-0.10839844  1.9775391  -0.23828125 -0.41308594]
#   [-0.3173828   2.1083984  -0.27441406 -0.3095703 ]
#   [-0.31835938  2.118164   -0.26953125 -0.3095703 ]
#   ...
#   [-0.15722656  2.15625     0.00878906 -0.5908203 ]
#   [-0.49414062  2.0136719  -0.2783203  -0.3203125 ]
#   [-0.2626953   1.9716797  -0.29882812 -0.20898438]]
#
#  [[-0.01367188  1.8242188  -0.07617188 -0.41210938]
#   [-0.19921875  1.9550781  -0.4716797  -0.2998047 ]
#   [-0.31347656  2.0898438  -0.29492188 -0.3125    ]
#   ...
#   [-0.43945312  2.0341797  -0.29101562 -0.3125    ]
#   [-0.29492188  1.9384766  -0.3251953  -0.29101562]
#   [-0.31054688  2.0507812  -0.3701172  -0.13476562]]
#
#  [[-0.23535156  2.1513672  -0.08398438 -0.2626953 ]
#   [-0.38964844  1.8222656  -0.3798828  -0.265625  ]
#   [-0.203125    1.9257812  -0.29003906 -0.2919922 ]
#   ...
#   [-0.3095703   2.0078125  -0.3955078  -0.31054688]
#   [-1.2519531   1.5419922  -0.4736328  -0.14160156]
#   [-0.39453125  0.48535156 -0.2919922  -0.29296875]]]

# %%
print("Keras  Accuracy: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_keras, axis=1))))
print("hls4ml Accuracy: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_hls, axis=1))))
fig, ax = plt.subplots(figsize=(9, 9))
_ = plotting.makeRoc(y_test, y_keras, classes)
plt.gca().set_prop_cycle(None)  # reset the colors
_ = plotting.makeRoc(y_test, y_hls, classes, linestyle='--')

from matplotlib.lines import Line2D

lines = [Line2D([0], [0], ls='-'), Line2D([0], [0], ls='--')]
from matplotlib.legend import Legend

leg = Legend(ax, lines, labels=['keras', 'hls4ml'], loc='lower right', frameon=False)
ax.add_artist(leg)
# Out:
# Keras  Accuracy: 0.3782051282051282
# hls4ml Accuracy: 0.23076923076923078
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]

# %%
config = hls4ml.utils.config_from_keras_model(model, granularity='Model')
print("-----------------------------------")
print(config)
print("-----------------------------------")
# Set the ReuseFactor to 2 throughout
config['Model']['ReuseFactor'] = 2
hls_model = hls4ml.converters.convert_from_keras_model(
    model, hls_config=config, output_dir='model_1/hls4ml_prj_2', part='xcu250-figd2104-2L-e'
)
hls_model.compile()
y_hls = hls_model.predict(X_test)
print("Keras  Accuracy: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_keras, axis=1))))
print("hls4ml Accuracy: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_hls, axis=1))))
# Out:
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# -----------------------------------
# {'Model': {'Precision': 'fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency', 'BramFactor': 1000000000, 'TraceOutput': False}}
# -----------------------------------
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# Creating HLS model
# WARNING: Layer conv1 requires "dataflow" pipeline style. Switching to "dataflow" pipeline style.
# Writing HLS project
# Done
# Keras  Accuracy: 0.3782051282051282
# hls4ml Accuracy: 0.22435897435897437

# %% [raw]
# Part 3

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
seed = 0
np.random.seed(seed)
import tensorflow as tf

tf.random.set_seed(seed)
import os

# %%
X_train_val = np.load('X_train_val.npy')
X_test = np.load('X_test.npy')
y_train_val = np.load('y_train_val.npy')
y_test = np.load('y_test.npy')
classes = np.load('classes.npy', allow_pickle=True)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from tensorflow.keras.regularizers import l1
from callbacks import all_callbacks

# %%
DATA_DIR = "PokerDataset"  
IMAGE_WIDTH = 64
IMAGE_HEIGHT = 64
TEST_SIZE = 0.2
NUM_CLASSES = 52

# %%
model = Sequential()
model.add(Conv2D(4, (3, 3), activation='relu', input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3), name='conv1'))
model.add(MaxPooling2D(pool_size=(2, 2), name='maxpool1'))
model.add(Conv2D(8, (3, 3), activation='relu', name='conv2'))
model.add(MaxPooling2D(pool_size=(2, 2), name='maxpool2'))
model.add(Flatten(name='flatten'))
model.add(Dense(32, activation='relu', name='dense1'))
model.add(Dense(NUM_CLASSES, activation='softmax', name='output'))

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning

pruning_params = {"pruning_schedule": pruning_schedule.ConstantSparsity(0.75, begin_step=2000, frequency=100)}
model = prune.prune_low_magnitude(model, **pruning_params)
# Out:
# WARNING:tensorflow:From /home/esp2024/rht2122/miniconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/esp2024/rht2122/miniconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
train = True
if train:
    adam = Adam(lr=0.01)
    model.compile(optimizer=adam, loss=['categorical_crossentropy'], metrics=['accuracy'])
    callbacks = all_callbacks(
        stop_patience=1000,
        lr_factor=0.5,
        lr_patience=10,
        lr_epsilon=0.000001,
        lr_cooldown=2,
        lr_minimum=0.0000001,
        outputDir='model_2',
    )
    callbacks.callbacks.append(pruning_callbacks.UpdatePruningStep())
    model.fit(
        X_train_val,
        y_train_val,
        batch_size=10,
        epochs=50,
        validation_split=0.25,
        shuffle=True,
        callbacks=callbacks.callbacks,
    )
    # Save the model again but with the pruning 'stripped' to use the regular layer types
    model = strip_pruning(model)
    model.save('model_2/KERAS_check_best_model.h5')
else:
    from tensorflow.keras.models import load_model

    model = load_model('model_2/KERAS_check_best_model.h5')
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 46/47 [============================>.] - ETA: 0s - loss: 3.9675 - accuracy: 0.0109
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 1: val_loss improved from inf to 3.96202, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 1: val_loss improved from inf to 3.96202, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 1: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 1: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 6s 23ms/step - loss: 3.9683 - accuracy: 0.0107 - val_loss: 3.9620 - val_accuracy: 0.0256 - lr: 0.0010
# Epoch 2/50
# 44/47 [===========================>..] - ETA: 0s - loss: 3.9424 - accuracy: 0.0159
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 2: val_loss improved from 3.96202 to 3.96012, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 2: val_loss improved from 3.96202 to 3.96012, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 2: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 2: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 3.9418 - accuracy: 0.0150 - val_loss: 3.9601 - val_accuracy: 0.0192 - lr: 0.0010
# Epoch 3/50
# 45/47 [===========================>..] - ETA: 0s - loss: 3.9149 - accuracy: 0.0333
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 3: val_loss improved from 3.96012 to 3.94396, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 3: val_loss improved from 3.96012 to 3.94396, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 3: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 3: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 17ms/step - loss: 3.9168 - accuracy: 0.0321 - val_loss: 3.9440 - val_accuracy: 0.0385 - lr: 0.0010
# Epoch 4/50
# 44/47 [===========================>..] - ETA: 0s - loss: 3.8341 - accuracy: 0.0523
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 4: val_loss improved from 3.94396 to 3.90721, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 4: val_loss improved from 3.94396 to 3.90721, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 4: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 4: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 17ms/step - loss: 3.8337 - accuracy: 0.0534 - val_loss: 3.9072 - val_accuracy: 0.0256 - lr: 0.0010
# Epoch 5/50
# 46/47 [============================>.] - ETA: 0s - loss: 3.6788 - accuracy: 0.0804
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 5: val_loss improved from 3.90721 to 3.81292, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 5: val_loss improved from 3.90721 to 3.81292, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 5: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 5: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 3.6714 - accuracy: 0.0812 - val_loss: 3.8129 - val_accuracy: 0.0513 - lr: 0.0010
# Epoch 6/50
# 46/47 [============================>.] - ETA: 0s - loss: 3.4204 - accuracy: 0.1543
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 6: val_loss improved from 3.81292 to 3.66359, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 6: val_loss improved from 3.81292 to 3.66359, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 6: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 6: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 3.4246 - accuracy: 0.1538 - val_loss: 3.6636 - val_accuracy: 0.0705 - lr: 0.0010
# Epoch 7/50
# 47/47 [==============================] - ETA: 0s - loss: 3.0854 - accuracy: 0.2051
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 7: val_loss improved from 3.66359 to 3.31161, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 7: val_loss improved from 3.66359 to 3.31161, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 7: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 7: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 18ms/step - loss: 3.0854 - accuracy: 0.2051 - val_loss: 3.3116 - val_accuracy: 0.1603 - lr: 0.0010
# Epoch 8/50
# 46/47 [============================>.] - ETA: 0s - loss: 2.6559 - accuracy: 0.2913
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 8: val_loss improved from 3.31161 to 3.24378, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 8: val_loss improved from 3.31161 to 3.24378, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 8: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 8: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 2.6580 - accuracy: 0.2906 - val_loss: 3.2438 - val_accuracy: 0.1218 - lr: 0.0010
# Epoch 9/50
# 46/47 [============================>.] - ETA: 0s - loss: 2.2323 - accuracy: 0.4304
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 9: val_loss improved from 3.24378 to 2.71860, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 9: val_loss improved from 3.24378 to 2.71860, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 9: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 9: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 24ms/step - loss: 2.2312 - accuracy: 0.4295 - val_loss: 2.7186 - val_accuracy: 0.3013 - lr: 0.0010
# Epoch 10/50
# 45/47 [===========================>..] - ETA: 0s - loss: 1.8259 - accuracy: 0.5067
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 10: val_loss improved from 2.71860 to 2.64362, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 10: val_loss improved from 2.71860 to 2.64362, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 10: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 10: saving model to model_2/KERAS_check_model_last_weights.h5
#
# Epoch 10: saving model to model_2/KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 17ms/step - loss: 1.8260 - accuracy: 0.5043 - val_loss: 2.6436 - val_accuracy: 0.2564 - lr: 0.0010
# Epoch 11/50
# 44/47 [===========================>..] - ETA: 0s - loss: 1.5339 - accuracy: 0.5750
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 11: val_loss improved from 2.64362 to 2.31333, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 11: val_loss improved from 2.64362 to 2.31333, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 11: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 11: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 1.5257 - accuracy: 0.5748 - val_loss: 2.3133 - val_accuracy: 0.3654 - lr: 0.0010
# Epoch 12/50
# 46/47 [============================>.] - ETA: 0s - loss: 1.2548 - accuracy: 0.6370
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 12: val_loss improved from 2.31333 to 2.26573, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 12: val_loss improved from 2.31333 to 2.26573, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 12: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 12: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 1.2502 - accuracy: 0.6368 - val_loss: 2.2657 - val_accuracy: 0.3526 - lr: 0.0010
# Epoch 13/50
# 47/47 [==============================] - ETA: 0s - loss: 1.0223 - accuracy: 0.7265
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 13: val_loss improved from 2.26573 to 2.21257, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 13: val_loss improved from 2.26573 to 2.21257, saving model to model_2/KERAS_check_best_model_weights.h5
# Epoch 13: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 13: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 18ms/step - loss: 1.0223 - accuracy: 0.7265 - val_loss: 2.2126 - val_accuracy: 0.3397 - lr: 0.0010
# Epoch 14/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.9115 - accuracy: 0.7370
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 14: val_loss did not improve from 2.21257
#
# Epoch 14: val_loss did not improve from 2.21257
#
# Epoch 14: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 14: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.9128 - accuracy: 0.7350 - val_loss: 2.2146 - val_accuracy: 0.4038 - lr: 0.0010
# Epoch 15/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.7307 - accuracy: 0.7800
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 15: val_loss did not improve from 2.21257
#
# Epoch 15: val_loss did not improve from 2.21257
#
# Epoch 15: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 15: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 0.7377 - accuracy: 0.7821 - val_loss: 2.2849 - val_accuracy: 0.4359 - lr: 0.0010
# Epoch 16/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.6120 - accuracy: 0.8511
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 16: val_loss improved from 2.21257 to 2.17459, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 16: val_loss improved from 2.21257 to 2.17459, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 16: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 16: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 0.6126 - accuracy: 0.8504 - val_loss: 2.1746 - val_accuracy: 0.4295 - lr: 0.0010
# Epoch 17/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.5224 - accuracy: 0.8778
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 17: val_loss improved from 2.17459 to 2.15207, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 17: val_loss improved from 2.17459 to 2.15207, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 17: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 17: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 0.5210 - accuracy: 0.8803 - val_loss: 2.1521 - val_accuracy: 0.4615 - lr: 0.0010
# Epoch 18/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.4541 - accuracy: 0.8935
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 18: val_loss did not improve from 2.15207
#
# Epoch 18: val_loss did not improve from 2.15207
#
# Epoch 18: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 18: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 0.4566 - accuracy: 0.8932 - val_loss: 2.2300 - val_accuracy: 0.4359 - lr: 0.0010
# Epoch 19/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.4062 - accuracy: 0.9022
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 19: val_loss improved from 2.15207 to 2.14384, saving model to model_2/KERAS_check_best_model.h5
#
# Epoch 19: val_loss improved from 2.15207 to 2.14384, saving model to model_2/KERAS_check_best_model_weights.h5
#
# Epoch 19: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 19: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 18ms/step - loss: 0.4043 - accuracy: 0.9038 - val_loss: 2.1438 - val_accuracy: 0.4808 - lr: 0.0010
# Epoch 20/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.3059 - accuracy: 0.9348
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 20: val_loss did not improve from 2.14384
#
# Epoch 20: val_loss did not improve from 2.14384
#
# Epoch 20: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 20: saving model to model_2/KERAS_check_model_last_weights.h5
#
# Epoch 20: saving model to model_2/KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 19ms/step - loss: 0.3042 - accuracy: 0.9338 - val_loss: 2.2518 - val_accuracy: 0.4744 - lr: 0.0010
# Epoch 21/50
# 43/47 [==========================>...] - ETA: 0s - loss: 0.2704 - accuracy: 0.9512
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 21: val_loss did not improve from 2.14384
#
# Epoch 21: val_loss did not improve from 2.14384
#
# Epoch 21: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 21: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 17ms/step - loss: 0.2773 - accuracy: 0.9466 - val_loss: 2.1787 - val_accuracy: 0.5128 - lr: 0.0010
# Epoch 22/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.2195 - accuracy: 0.9609
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 22: val_loss did not improve from 2.14384
#
# Epoch 22: val_loss did not improve from 2.14384
#
# Epoch 22: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 22: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.2279 - accuracy: 0.9573 - val_loss: 2.3464 - val_accuracy: 0.4936 - lr: 0.0010
# Epoch 23/50
# 44/47 [===========================>..] - ETA: 0s - loss: 0.1928 - accuracy: 0.9614
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 23: val_loss did not improve from 2.14384
#
# Epoch 23: val_loss did not improve from 2.14384
#
# Epoch 23: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 23: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 0.1928 - accuracy: 0.9615 - val_loss: 2.2785 - val_accuracy: 0.5192 - lr: 0.0010
# Epoch 24/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.1568 - accuracy: 0.9822
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 24: val_loss did not improve from 2.14384
#
# Epoch 24: val_loss did not improve from 2.14384
#
# Epoch 24: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 24: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.1523 - accuracy: 0.9829 - val_loss: 2.3470 - val_accuracy: 0.5128 - lr: 0.0010
# Epoch 25/50
# 44/47 [===========================>..] - ETA: 0s - loss: 0.1181 - accuracy: 0.9886
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 25: val_loss did not improve from 2.14384
#
# Epoch 25: val_loss did not improve from 2.14384
#
# Epoch 25: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 25: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 17ms/step - loss: 0.1180 - accuracy: 0.9893 - val_loss: 2.3998 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 26/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.1011 - accuracy: 0.9956
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 26: val_loss did not improve from 2.14384
#
# Epoch 26: val_loss did not improve from 2.14384
#
# Epoch 26: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 26: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 0.1047 - accuracy: 0.9936 - val_loss: 2.3692 - val_accuracy: 0.5256 - lr: 0.0010
# Epoch 27/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9936
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 27: val_loss did not improve from 2.14384
#
# Epoch 27: val_loss did not improve from 2.14384
#
# Epoch 27: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 27: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0912 - accuracy: 0.9936 - val_loss: 2.5142 - val_accuracy: 0.5705 - lr: 0.0010
# Epoch 28/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0739 - accuracy: 0.9957
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 28: val_loss did not improve from 2.14384
#
# Epoch 28: val_loss did not improve from 2.14384
#
# Epoch 28: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 28: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0755 - accuracy: 0.9957 - val_loss: 2.4550 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 29/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0653 - accuracy: 0.9957
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 29: val_loss did not improve from 2.14384
#
# Epoch 29: val_loss did not improve from 2.14384
#
# Epoch 29: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 29: saving model to model_2/KERAS_check_model_last_weights.h5
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0653 - accuracy: 0.9957 - val_loss: 2.6703 - val_accuracy: 0.5641 - lr: 0.0010
# Epoch 30/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.0502 - accuracy: 0.9978
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 30: val_loss did not improve from 2.14384
#
# Epoch 30: val_loss did not improve from 2.14384
#
# Epoch 30: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 30: saving model to model_2/KERAS_check_model_last_weights.h5
#
# Epoch 30: saving model to model_2/KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0497 - accuracy: 0.9979 - val_loss: 2.5596 - val_accuracy: 0.5897 - lr: 5.0000e-04
# Epoch 31/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 1.0000
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 31: val_loss did not improve from 2.14384
#
# Epoch 31: val_loss did not improve from 2.14384
#
# Epoch 31: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 31: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 17ms/step - loss: 0.0412 - accuracy: 1.0000 - val_loss: 2.5654 - val_accuracy: 0.5962 - lr: 5.0000e-04
# Epoch 32/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0391 - accuracy: 1.0000
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 32: val_loss did not improve from 2.14384
#
# Epoch 32: val_loss did not improve from 2.14384
#
# Epoch 32: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 32: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0388 - accuracy: 1.0000 - val_loss: 2.5826 - val_accuracy: 0.5769 - lr: 5.0000e-04
# Epoch 33/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.0366 - accuracy: 1.0000
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 33: val_loss did not improve from 2.14384
#
# Epoch 33: val_loss did not improve from 2.14384
#
# Epoch 33: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 33: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 2.6367 - val_accuracy: 0.5833 - lr: 5.0000e-04
# Epoch 34/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.0348 - accuracy: 1.0000
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 34: val_loss did not improve from 2.14384
#
# Epoch 34: val_loss did not improve from 2.14384
#
# Epoch 34: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 34: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0345 - accuracy: 1.0000 - val_loss: 2.5972 - val_accuracy: 0.6026 - lr: 5.0000e-04
# Epoch 35/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 1.0000
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 35: val_loss did not improve from 2.14384
#
# Epoch 35: val_loss did not improve from 2.14384
#
# Epoch 35: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 35: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0317 - accuracy: 1.0000 - val_loss: 2.6788 - val_accuracy: 0.5962 - lr: 5.0000e-04
# Epoch 36/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0298 - accuracy: 1.0000
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 36: val_loss did not improve from 2.14384
#
# Epoch 36: val_loss did not improve from 2.14384
#
# Epoch 36: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 36: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 2.6692 - val_accuracy: 0.5962 - lr: 5.0000e-04
# Epoch 37/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0295 - accuracy: 1.0000
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 37: val_loss did not improve from 2.14384
#
# Epoch 37: val_loss did not improve from 2.14384
#
# Epoch 37: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 37: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 2.6690 - val_accuracy: 0.5897 - lr: 5.0000e-04
# Epoch 38/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.0276 - accuracy: 1.0000
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 38: val_loss did not improve from 2.14384
#
# Epoch 38: val_loss did not improve from 2.14384
#
# Epoch 38: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 38: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0268 - accuracy: 1.0000 - val_loss: 2.6959 - val_accuracy: 0.5897 - lr: 5.0000e-04
# Epoch 39/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.0242 - accuracy: 1.0000
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 39: val_loss did not improve from 2.14384
#
# Epoch 39: val_loss did not improve from 2.14384
#
# Epoch 39: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 39: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 2.7498 - val_accuracy: 0.6026 - lr: 5.0000e-04
# Epoch 40/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 1.0000
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 40: val_loss did not improve from 2.14384
#
# Epoch 40: val_loss did not improve from 2.14384
#
# Epoch 40: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 40: saving model to model_2/KERAS_check_model_last_weights.h5
#
# Epoch 40: saving model to model_2/KERAS_check_model_epoch40.h5
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 2.7317 - val_accuracy: 0.6026 - lr: 5.0000e-04
# Epoch 41/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.0216 - accuracy: 1.0000
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 41: val_loss did not improve from 2.14384
#
# Epoch 41: val_loss did not improve from 2.14384
#
# Epoch 41: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 41: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 2.7565 - val_accuracy: 0.5962 - lr: 2.5000e-04
# Epoch 42/50
# 44/47 [===========================>..] - ETA: 0s - loss: 0.0214 - accuracy: 1.0000
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 42: val_loss did not improve from 2.14384
#
# Epoch 42: val_loss did not improve from 2.14384
#
# Epoch 42: saving model to model_2/KERAS_check_model_last.h5
# Epoch 42: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 2.7725 - val_accuracy: 0.5962 - lr: 2.5000e-04
# Epoch 43/50
# 46/47 [============================>.] - ETA: 0s - loss: 2.1708 - accuracy: 0.6500
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 43: val_loss did not improve from 2.14384
#
# Epoch 43: val_loss did not improve from 2.14384
#
# Epoch 43: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 43: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 2.1742 - accuracy: 0.6474 - val_loss: 3.6269 - val_accuracy: 0.2115 - lr: 2.5000e-04
# Epoch 44/50
# 46/47 [============================>.] - ETA: 0s - loss: 2.6554 - accuracy: 0.3435
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 44: val_loss did not improve from 2.14384
#
# Epoch 44: val_loss did not improve from 2.14384
#
# Epoch 44: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 44: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 2.6486 - accuracy: 0.3462 - val_loss: 3.0329 - val_accuracy: 0.2372 - lr: 2.5000e-04
# Epoch 45/50
# 46/47 [============================>.] - ETA: 0s - loss: 2.3570 - accuracy: 0.4065
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 45: val_loss did not improve from 2.14384
#
# Epoch 45: val_loss did not improve from 2.14384
#
# Epoch 45: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 45: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 2.3515 - accuracy: 0.4060 - val_loss: 2.9278 - val_accuracy: 0.2436 - lr: 2.5000e-04
# Epoch 46/50
# 46/47 [============================>.] - ETA: 0s - loss: 2.1882 - accuracy: 0.4326
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 46: val_loss did not improve from 2.14384
#
# Epoch 46: val_loss did not improve from 2.14384
#
# Epoch 46: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 46: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 2.1847 - accuracy: 0.4338 - val_loss: 2.8502 - val_accuracy: 0.2436 - lr: 2.5000e-04
# Epoch 47/50
# 46/47 [============================>.] - ETA: 0s - loss: 2.0843 - accuracy: 0.4457
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 47: val_loss did not improve from 2.14384
#
# Epoch 47: val_loss did not improve from 2.14384
#
# Epoch 47: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 47: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 2.0683 - accuracy: 0.4509 - val_loss: 2.8049 - val_accuracy: 0.2436 - lr: 2.5000e-04
# Epoch 48/50
# 46/47 [============================>.] - ETA: 0s - loss: 1.9827 - accuracy: 0.4761
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 48: val_loss did not improve from 2.14384
#
# Epoch 48: val_loss did not improve from 2.14384
#
# Epoch 48: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 48: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 15ms/step - loss: 1.9699 - accuracy: 0.4786 - val_loss: 2.7403 - val_accuracy: 0.2372 - lr: 2.5000e-04
# Epoch 49/50
# 45/47 [===========================>..] - ETA: 0s - loss: 1.9104 - accuracy: 0.4778
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 49: val_loss did not improve from 2.14384
#
# Epoch 49: val_loss did not improve from 2.14384
#
# Epoch 49: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 49: saving model to model_2/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 1.9010 - accuracy: 0.4829 - val_loss: 2.7156 - val_accuracy: 0.2436 - lr: 2.5000e-04
# Epoch 50/50
# 44/47 [===========================>..] - ETA: 0s - loss: 1.8229 - accuracy: 0.5114
# ***callbacks***
# saving losses to model_2/losses.log
#
# Epoch 50: val_loss did not improve from 2.14384
#
# Epoch 50: val_loss did not improve from 2.14384
#
# Epoch 50: saving model to model_2/KERAS_check_model_last.h5
#
# Epoch 50: saving model to model_2/KERAS_check_model_last_weights.h5
#
# Epoch 50: saving model to model_2/KERAS_check_model_epoch50.h5
#
# ***callbacks end***
#
# 47/47 [==============================] - 1s 16ms/step - loss: 1.8343 - accuracy: 0.5064 - val_loss: 2.6801 - val_accuracy: 0.2692 - lr: 2.5000e-04
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
w = model.layers[0].weights[0].numpy()
h, b = np.histogram(w, bins=100)
plt.figure(figsize=(7, 7))
plt.bar(b[:-1], h, width=b[1] - b[0])
plt.semilogy()
print('% of zeros = {}'.format(np.sum(w == 0) / np.size(w)))
# Out:
# % of zeros = 0.75

# %%
import plotting
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model

model_ref = load_model('model_1/KERAS_check_best_model.h5')

y_ref = model_ref.predict(X_test)
y_prune = model.predict(X_test)

print("Accuracy unpruned: {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_ref, axis=1))))
print("Accuracy pruned:   {}".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_prune, axis=1))))

fig, ax = plt.subplots(figsize=(9, 9))
_ = plotting.makeRoc(y_test, y_ref, classes)
plt.gca().set_prop_cycle(None)  # reset the colors
_ = plotting.makeRoc(y_test, y_prune, classes, linestyle='--')

from matplotlib.lines import Line2D

lines = [Line2D([0], [0], ls='-'), Line2D([0], [0], ls='--')]
from matplotlib.legend import Legend

leg = Legend(ax, lines, labels=['unpruned', 'pruned'], loc='lower right', frameon=False)
ax.add_artist(leg)
# Out:
# 5/5 [==============================] - 0s 10ms/step
# 5/5 [==============================] - 0s 10ms/step
# Accuracy unpruned: 0.3782051282051282
# Accuracy pruned:   0.27564102564102566
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:64: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label] = y[:, i]
# /home/esp2024/rht2122/PokerML/PokerML/plotting.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[label + '_pred'] = predict_test[:, i]

# %%
import hls4ml

config = hls4ml.utils.config_from_keras_model(model, granularity='model')
print(config)
hls_model = hls4ml.converters.convert_from_keras_model(
    model, hls_config=config, output_dir='model_2/hls4ml_prj', part='xcu250-figd2104-2L-e'
)
hls_model.compile()
# Out:
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# {'Model': {'Precision': 'fixed<16,6>', 'ReuseFactor': 1, 'Strategy': 'Latency', 'BramFactor': 1000000000, 'TraceOutput': False}}
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# Creating HLS model
# WARNING: Layer conv1 requires "dataflow" pipeline style. Switching to "dataflow" pipeline style.
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done

# %% [markdown]
# Part 4

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
seed = 0
np.random.seed(seed)
import tensorflow as tf

tf.random.set_seed(seed)
import os

# %%
X_train_val = np.load('X_train_val.npy')
X_test = np.load('X_test.npy')
y_train_val = np.load('y_train_val.npy')
y_test = np.load('y_test.npy')
classes = np.load('classes.npy', allow_pickle=True)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1
from callbacks import all_callbacks
from tensorflow.keras.layers import Activation
from qkeras.qlayers import QDense, QActivation
from qkeras.quantizers import quantized_bits, quantized_relu

# %%
model = Sequential()
model.add(Conv2D(4, (3, 3), input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3), name='conv1'))
model.add(QActivation(activation=quantized_relu(6), name='relu1'))
model.add(MaxPooling2D(pool_size=(2, 2), name='maxpool1'))
model.add(Conv2D(8, (3, 3), name='conv2'))
model.add(QActivation(activation=quantized_relu(6), name='relu2'))
model.add(MaxPooling2D(pool_size=(2, 2), name='maxpool2'))
model.add(Flatten(name='flatten'))
model.add(Dense(32,name='dense1'))
model.add(QActivation(activation=quantized_relu(6), name='relu3'))
model.add(Dense(NUM_CLASSES, activation='softmax', name='output'))
