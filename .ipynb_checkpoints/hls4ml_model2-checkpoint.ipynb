# %% [markdown]
# # PokerML

# %%
# Disable some console warnings
import os
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
import numpy as np

from sklearn.preprocessing import LabelEncoder 
from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.image import img_to_array, load_img
from keras.utils import to_categorical

# %% [markdown]
# Make sure that you have Vivado suite in your environment.

# %%
os.environ['PATH'] = os.environ['XILINX_VIVADO'] + '/bin:' + os.environ['PATH']

# %%
# from tensorflow.keras.utils import to_categorical
# from sklearn.datasets import fetch_openml
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder, StandardScaler
# import numpy as np

# %matplotlib inline
# seed = 0
# np.random.seed(seed)
# import tensorflow as tf

# tf.random.set_seed(seed)
# import os

# os.environ['PATH'] = os.environ['XILINX_VIVADO'] + '/bin:' + os.environ['PATH']

# %% [markdown]
# ## Configuration

# %%
DATA_DIR = "data"

MODELS_DIR = 'models/'

DATA_JPG_DIR = DATA_DIR + '/augmented/jpg'
DATA_NPY_DIR = DATA_DIR + '/npy/'


IMAGE_WIDTH = 64
IMAGE_HEIGHT = 64
TEST_SIZE = 0.2
NUM_CLASSES = 52

CREATE_DATASET = True
KERAS_TRAIN = True
QKERAS_TRAIN = True

# %% [markdown]
# ## Create dataset

# %%
image_paths = []
labels = []

def preprocess_image(image_path):
    img = load_img(image_path, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))
    img_array = img_to_array(img) / 255.0  # Normalize pixel values
    return img_array

# %%
if CREATE_DATASET:

    for label in os.listdir(DATA_JPG_DIR):
        label_dir = os.path.join(DATA_JPG_DIR, label)
        for image_file in os.listdir(label_dir):
            image_paths.append(os.path.join(label_dir, image_file))
            labels.append(label)

    X_train_val, X_test, y_train_val, y_test = train_test_split(
        image_paths, labels, test_size=TEST_SIZE, random_state=42, stratify=labels)


    # Encode labels
    label_encoder = LabelEncoder()
    label_encoder.fit(y_train_val)
    y_train_val_encoded = label_encoder.transform(y_train_val)
    y_test_encoded = label_encoder.transform(y_test)


    # Convert integer labels to categorical format
    y_train_val = to_categorical(y_train_val_encoded, NUM_CLASSES)

    # Convert integer labels to categorical format
    y_test = to_categorical(y_test_encoded, NUM_CLASSES)

    # Verify one-hot encoding
    #print("Shape of y_train_val:", y_train_val.shape)
    #print("Shape of y_test:", y_test.shape)

    X_train_val = [preprocess_image(image_path) for image_path in X_train_val]
    X_test = [preprocess_image(image_path) for image_path in X_test]

    X_train_val = np.array(X_train_val)
    X_test = np.array(X_test)
    
    classes = label_encoder.classes_


    # Save the preprocessed data
    np.save(DATA_NPY_DIR + 'X_train_val.npy', X_train_val)
    np.save(DATA_NPY_DIR + 'X_test.npy', X_test)
    np.save(DATA_NPY_DIR + 'y_train_val.npy', y_train_val)
    np.save(DATA_NPY_DIR + 'y_test.npy', y_test)
    np.save(DATA_NPY_DIR + 'classes.npy', classes)
    
else:
    X_train_val = np.load(DATA_NPY_DIR + 'X_train_val.npy')
    X_test = np.load(DATA_NPY_DIR + 'X_test.npy')
    y_train_val = np.load(DATA_NPY_DIR + 'y_train_val.npy')
    y_test = np.load(DATA_NPY_DIR + 'y_test.npy')
    classes = np.load(DATA_NPY_DIR + 'classes.npy', allow_pickle=True)

# %%
print('Train and validation set:', X_train_val.shape[0])
print('Test set:                ', X_test.shape[0])
print('Classes:                 ', classes.shape[0])
# Out:
# Train and validation set: 19968
# Test set:                 4992
# Classes:                  52

# %% [markdown]
# ## Train Keras model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from tensorflow.keras.regularizers import l1
from callbacks import all_callbacks

# %%
if KERAS_TRAIN:
    model = Sequential()
    model.add(Conv2D(4, (3, 3), activation='relu', input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3), name='conv1'))
    model.add(MaxPooling2D(pool_size=(2, 2), name='maxpool1'))
    model.add(Conv2D(8, (3, 3), activation='relu', name='conv2'))
    model.add(MaxPooling2D(pool_size=(2, 2), name='maxpool2'))
    model.add(Flatten(name='flatten'))
    model.add(Dense(32, activation='relu', name='dense1'))
    model.add(Dense(NUM_CLASSES, activation='softmax', name='output'))
    
    print("Model summary:")
    model.summary()
# Out:
# Model summary:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 62, 62, 4)         112
#
#  maxpool1 (MaxPooling2D)     (None, 31, 31, 4)         0
#
#  conv2 (Conv2D)              (None, 29, 29, 8)         296
#
#  maxpool2 (MaxPooling2D)     (None, 14, 14, 8)         0
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense1 (Dense)              (None, 32)                50208
#
#  output (Dense)              (None, 52)                1716
#
# =================================================================
# Total params: 52,332
# Trainable params: 52,332
# Non-trainable params: 0
# _________________________________________________________________

# %%
if KERAS_TRAIN:
    adam = Adam(lr=0.01)
    model.compile(optimizer=adam, loss=['categorical_crossentropy'], metrics=['accuracy'])
    callbacks = all_callbacks(
        stop_patience=1000,
        lr_factor=0.5,
        lr_patience=10,
        lr_epsilon=0.000001,
        lr_cooldown=2,
        lr_minimum=0.0000001,
        outputDir=MODELS_DIR+'/keras',
    )
    history = model.fit(
        X_train_val,
        y_train_val,
        batch_size=10,
        epochs=50,
        validation_split=0.25,
        shuffle=True,
        callbacks=callbacks.callbacks,
    )

else:
    from tensorflow.keras.models import load_model

    model = load_model(MODELS_DIR + 'keras/check_best_model.h5')
    
    print("Model summary:")
    model.summary()
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 1492/1498 [============================>.] - ETA: 0s - loss: 3.2533 - accuracy: 0.1117
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 1: val_loss improved from inf to 2.49167, saving model to models//keras/check_best_model.h5
#
# Epoch 1: val_loss improved from inf to 2.49167, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 1: saving model to models//keras/check_model_last.h5
#
# Epoch 1: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 8s 5ms/step - loss: 3.2506 - accuracy: 0.1122 - val_loss: 2.4917 - val_accuracy: 0.2190 - lr: 0.0010
# Epoch 2/50
# 1497/1498 [============================>.] - ETA: 0s - loss: 2.1535 - accuracy: 0.2961
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 2: val_loss improved from 2.49167 to 1.82259, saving model to models//keras/check_best_model.h5
#
# Epoch 2: val_loss improved from 2.49167 to 1.82259, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 2: saving model to models//keras/check_model_last.h5
#
# Epoch 2: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 7s 5ms/step - loss: 2.1534 - accuracy: 0.2961 - val_loss: 1.8226 - val_accuracy: 0.3864 - lr: 0.0010
# Epoch 3/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 1.6792 - accuracy: 0.4127
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 3: val_loss improved from 1.82259 to 1.55934, saving model to models//keras/check_best_model.h5
#
# Epoch 3: val_loss improved from 1.82259 to 1.55934, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 3: saving model to models//keras/check_model_last.h5
#
# Epoch 3: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 7s 5ms/step - loss: 1.6789 - accuracy: 0.4128 - val_loss: 1.5593 - val_accuracy: 0.4445 - lr: 0.0010
# Epoch 4/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 1.4429 - accuracy: 0.4821
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 4: val_loss improved from 1.55934 to 1.42625, saving model to models//keras/check_best_model.h5
#
# Epoch 4: val_loss improved from 1.55934 to 1.42625, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 4: saving model to models//keras/check_model_last.h5
#
# Epoch 4: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 7s 5ms/step - loss: 1.4422 - accuracy: 0.4822 - val_loss: 1.4263 - val_accuracy: 0.4862 - lr: 0.0010
# Epoch 5/50
# 1491/1498 [============================>.] - ETA: 0s - loss: 1.2855 - accuracy: 0.5357
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 5: val_loss improved from 1.42625 to 1.22023, saving model to models//keras/check_best_model.h5
#
# Epoch 5: val_loss improved from 1.42625 to 1.22023, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 5: saving model to models//keras/check_model_last.h5
#
# Epoch 5: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 7s 5ms/step - loss: 1.2848 - accuracy: 0.5357 - val_loss: 1.2202 - val_accuracy: 0.5607 - lr: 0.0010
# Epoch 6/50
# 1497/1498 [============================>.] - ETA: 0s - loss: 1.1507 - accuracy: 0.5865
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 6: val_loss improved from 1.22023 to 1.18548, saving model to models//keras/check_best_model.h5
#
# Epoch 6: val_loss improved from 1.22023 to 1.18548, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 6: saving model to models//keras/check_model_last.h5
#
# Epoch 6: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 7s 5ms/step - loss: 1.1506 - accuracy: 0.5865 - val_loss: 1.1855 - val_accuracy: 0.5789 - lr: 0.0010
# Epoch 7/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 1.0636 - accuracy: 0.6225
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 7: val_loss improved from 1.18548 to 1.10662, saving model to models//keras/check_best_model.h5
#
# Epoch 7: val_loss improved from 1.18548 to 1.10662, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 7: saving model to models//keras/check_model_last.h5
#
# Epoch 7: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 7s 5ms/step - loss: 1.0635 - accuracy: 0.6224 - val_loss: 1.1066 - val_accuracy: 0.6082 - lr: 0.0010
# Epoch 8/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 0.9850 - accuracy: 0.6521
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 8: val_loss did not improve from 1.10662
#
# Epoch 8: val_loss did not improve from 1.10662
#
# Epoch 8: saving model to models//keras/check_model_last.h5
#
# Epoch 8: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 7s 5ms/step - loss: 0.9851 - accuracy: 0.6520 - val_loss: 1.1077 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 9/50
# 1480/1498 [============================>.] - ETA: 0s - loss: 0.9302 - accuracy: 0.6691
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 9: val_loss improved from 1.10662 to 0.99820, saving model to models//keras/check_best_model.h5
#
# Epoch 9: val_loss improved from 1.10662 to 0.99820, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 9: saving model to models//keras/check_model_last.h5
#
# Epoch 9: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 6s 4ms/step - loss: 0.9302 - accuracy: 0.6688 - val_loss: 0.9982 - val_accuracy: 0.6450 - lr: 0.0010
# Epoch 10/50
# 1491/1498 [============================>.] - ETA: 0s - loss: 0.8831 - accuracy: 0.6848
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 10: val_loss did not improve from 0.99820
#
# Epoch 10: val_loss did not improve from 0.99820
#
# Epoch 10: saving model to models//keras/check_model_last.h5
#
# Epoch 10: saving model to models//keras/check_model_last_weights.h5
#
# Epoch 10: saving model to models//keras/check_model_epoch10.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 3ms/step - loss: 0.8824 - accuracy: 0.6850 - val_loss: 1.0208 - val_accuracy: 0.6496 - lr: 0.0010
# Epoch 11/50
# 1491/1498 [============================>.] - ETA: 0s - loss: 0.8522 - accuracy: 0.7004
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 11: val_loss improved from 0.99820 to 0.90086, saving model to models//keras/check_best_model.h5
#
# Epoch 11: val_loss improved from 0.99820 to 0.90086, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 11: saving model to models//keras/check_model_last.h5
#
# Epoch 11: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 7s 5ms/step - loss: 0.8524 - accuracy: 0.7003 - val_loss: 0.9009 - val_accuracy: 0.6867 - lr: 0.0010
# Epoch 12/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 0.8052 - accuracy: 0.7174
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 12: val_loss improved from 0.90086 to 0.88715, saving model to models//keras/check_best_model.h5
#
# Epoch 12: val_loss improved from 0.90086 to 0.88715, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 12: saving model to models//keras/check_model_last.h5
#
# Epoch 12: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 7s 5ms/step - loss: 0.8058 - accuracy: 0.7173 - val_loss: 0.8871 - val_accuracy: 0.6937 - lr: 0.0010
# Epoch 13/50
# 1490/1498 [============================>.] - ETA: 0s - loss: 0.7761 - accuracy: 0.7261
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 13: val_loss did not improve from 0.88715
#
# Epoch 13: val_loss did not improve from 0.88715
#
# Epoch 13: saving model to models//keras/check_model_last.h5
#
# Epoch 13: saving model to models//keras/check_model_last_weights.h5
# ***callbacks end***
#
# 1498/1498 [==============================] - 8s 5ms/step - loss: 0.7764 - accuracy: 0.7259 - val_loss: 0.9085 - val_accuracy: 0.6943 - lr: 0.0010
# Epoch 14/50
# 1487/1498 [============================>.] - ETA: 0s - loss: 0.7530 - accuracy: 0.7365
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 14: val_loss did not improve from 0.88715
#
# Epoch 14: val_loss did not improve from 0.88715
#
# Epoch 14: saving model to models//keras/check_model_last.h5
#
# Epoch 14: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 6s 4ms/step - loss: 0.7532 - accuracy: 0.7363 - val_loss: 0.9157 - val_accuracy: 0.6905 - lr: 0.0010
# Epoch 15/50
# 1489/1498 [============================>.] - ETA: 0s - loss: 0.7286 - accuracy: 0.7456
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 15: val_loss did not improve from 0.88715
#
# Epoch 15: val_loss did not improve from 0.88715
#
# Epoch 15: saving model to models//keras/check_model_last.h5
#
# Epoch 15: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 7s 4ms/step - loss: 0.7278 - accuracy: 0.7461 - val_loss: 0.8949 - val_accuracy: 0.6987 - lr: 0.0010
# Epoch 16/50
# 1497/1498 [============================>.] - ETA: 0s - loss: 0.7057 - accuracy: 0.7533
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 16: val_loss did not improve from 0.88715
#
# Epoch 16: val_loss did not improve from 0.88715
#
# Epoch 16: saving model to models//keras/check_model_last.h5
#
# Epoch 16: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 8s 6ms/step - loss: 0.7058 - accuracy: 0.7533 - val_loss: 0.9304 - val_accuracy: 0.6929 - lr: 0.0010
# Epoch 17/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 0.6834 - accuracy: 0.7588
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 17: val_loss did not improve from 0.88715
#
# Epoch 17: val_loss did not improve from 0.88715
#
# Epoch 17: saving model to models//keras/check_model_last.h5
#
# Epoch 17: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 6s 4ms/step - loss: 0.6833 - accuracy: 0.7589 - val_loss: 0.8890 - val_accuracy: 0.7049 - lr: 0.0010
# Epoch 18/50
# 1498/1498 [==============================] - ETA: 0s - loss: 0.6678 - accuracy: 0.7654
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 18: val_loss did not improve from 0.88715
#
# Epoch 18: val_loss did not improve from 0.88715
#
# Epoch 18: saving model to models//keras/check_model_last.h5
#
# Epoch 18: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 8s 5ms/step - loss: 0.6678 - accuracy: 0.7654 - val_loss: 0.9030 - val_accuracy: 0.7063 - lr: 0.0010
# Epoch 19/50
# 1492/1498 [============================>.] - ETA: 0s - loss: 0.6431 - accuracy: 0.7761
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 19: val_loss improved from 0.88715 to 0.87660, saving model to models//keras/check_best_model.h5
#
# Epoch 19: val_loss improved from 0.88715 to 0.87660, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 19: saving model to models//keras/check_model_last.h5
#
# Epoch 19: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.6438 - accuracy: 0.7757 - val_loss: 0.8766 - val_accuracy: 0.7133 - lr: 0.0010
# Epoch 20/50
# 1493/1498 [============================>.] - ETA: 0s - loss: 0.6320 - accuracy: 0.7761
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 20: val_loss did not improve from 0.87660
#
# Epoch 20: val_loss did not improve from 0.87660
#
# Epoch 20: saving model to models//keras/check_model_last.h5
#
# Epoch 20: saving model to models//keras/check_model_last_weights.h5
#
# Epoch 20: saving model to models//keras/check_model_epoch20.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 2ms/step - loss: 0.6314 - accuracy: 0.7762 - val_loss: 0.8954 - val_accuracy: 0.7071 - lr: 0.0010
# Epoch 21/50
# 1490/1498 [============================>.] - ETA: 0s - loss: 0.6081 - accuracy: 0.7858
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 21: val_loss improved from 0.87660 to 0.86607, saving model to models//keras/check_best_model.h5
#
# Epoch 21: val_loss improved from 0.87660 to 0.86607, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 21: saving model to models//keras/check_model_last.h5
#
# Epoch 21: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 3ms/step - loss: 0.6092 - accuracy: 0.7855 - val_loss: 0.8661 - val_accuracy: 0.7179 - lr: 0.0010
# Epoch 22/50
# 1490/1498 [============================>.] - ETA: 0s - loss: 0.5879 - accuracy: 0.7934
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 22: val_loss improved from 0.86607 to 0.84342, saving model to models//keras/check_best_model.h5
#
# Epoch 22: val_loss improved from 0.86607 to 0.84342, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 22: saving model to models//keras/check_model_last.h5
#
# Epoch 22: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.5881 - accuracy: 0.7934 - val_loss: 0.8434 - val_accuracy: 0.7312 - lr: 0.0010
# Epoch 23/50
# 1485/1498 [============================>.] - ETA: 0s - loss: 0.5816 - accuracy: 0.7960
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 23: val_loss improved from 0.84342 to 0.83913, saving model to models//keras/check_best_model.h5
#
# Epoch 23: val_loss improved from 0.84342 to 0.83913, saving model to models//keras/check_best_model_weights.h5
#
# Epoch 23: saving model to models//keras/check_model_last.h5
#
# Epoch 23: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.5819 - accuracy: 0.7959 - val_loss: 0.8391 - val_accuracy: 0.7352 - lr: 0.0010
# Epoch 24/50
# 1481/1498 [============================>.] - ETA: 0s - loss: 0.5688 - accuracy: 0.7976
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 24: val_loss did not improve from 0.83913
#
# Epoch 24: val_loss did not improve from 0.83913
#
# Epoch 24: saving model to models//keras/check_model_last.h5
#
# Epoch 24: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.5693 - accuracy: 0.7973 - val_loss: 0.9071 - val_accuracy: 0.7147 - lr: 0.0010
# Epoch 25/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 0.5551 - accuracy: 0.8020
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 25: val_loss did not improve from 0.83913
#
# Epoch 25: val_loss did not improve from 0.83913
#
# Epoch 25: saving model to models//keras/check_model_last.h5
#
# Epoch 25: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.5549 - accuracy: 0.8019 - val_loss: 0.8986 - val_accuracy: 0.7230 - lr: 0.0010
# Epoch 26/50
# 1491/1498 [============================>.] - ETA: 0s - loss: 0.5432 - accuracy: 0.8097
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 26: val_loss did not improve from 0.83913
#
# Epoch 26: val_loss did not improve from 0.83913
#
# Epoch 26: saving model to models//keras/check_model_last.h5
#
# Epoch 26: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 6s 4ms/step - loss: 0.5437 - accuracy: 0.8095 - val_loss: 0.8701 - val_accuracy: 0.7366 - lr: 0.0010
# Epoch 27/50
# 1492/1498 [============================>.] - ETA: 0s - loss: 0.5249 - accuracy: 0.8162
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 27: val_loss did not improve from 0.83913
#
# Epoch 27: val_loss did not improve from 0.83913
#
# Epoch 27: saving model to models//keras/check_model_last.h5
# Epoch 27: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 4ms/step - loss: 0.5251 - accuracy: 0.8162 - val_loss: 0.9039 - val_accuracy: 0.7171 - lr: 0.0010
# Epoch 28/50
# 1495/1498 [============================>.] - ETA: 0s - loss: 0.5213 - accuracy: 0.8169
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 28: val_loss did not improve from 0.83913
#
# Epoch 28: val_loss did not improve from 0.83913
#
# Epoch 28: saving model to models//keras/check_model_last.h5
#
# Epoch 28: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 4ms/step - loss: 0.5218 - accuracy: 0.8168 - val_loss: 0.9303 - val_accuracy: 0.7256 - lr: 0.0010
# Epoch 29/50
# 1488/1498 [============================>.] - ETA: 0s - loss: 0.5059 - accuracy: 0.8199
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 29: val_loss did not improve from 0.83913
#
# Epoch 29: val_loss did not improve from 0.83913
#
# Epoch 29: saving model to models//keras/check_model_last.h5
#
# Epoch 29: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 3ms/step - loss: 0.5064 - accuracy: 0.8195 - val_loss: 0.9191 - val_accuracy: 0.7238 - lr: 0.0010
# Epoch 30/50
# 1492/1498 [============================>.] - ETA: 0s - loss: 0.4931 - accuracy: 0.8271
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 30: val_loss did not improve from 0.83913
#
# Epoch 30: val_loss did not improve from 0.83913
#
# Epoch 30: saving model to models//keras/check_model_last.h5
#
# Epoch 30: saving model to models//keras/check_model_last_weights.h5
#
# Epoch 30: saving model to models//keras/check_model_epoch30.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 3ms/step - loss: 0.4933 - accuracy: 0.8271 - val_loss: 0.9404 - val_accuracy: 0.7248 - lr: 0.0010
# Epoch 31/50
# 1482/1498 [============================>.] - ETA: 0s - loss: 0.4860 - accuracy: 0.8282
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 31: val_loss did not improve from 0.83913
#
# Epoch 31: val_loss did not improve from 0.83913
#
# Epoch 31: saving model to models//keras/check_model_last.h5
#
# Epoch 31: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 3ms/step - loss: 0.4854 - accuracy: 0.8283 - val_loss: 1.0551 - val_accuracy: 0.7105 - lr: 0.0010
# Epoch 32/50
# 1491/1498 [============================>.] - ETA: 0s - loss: 0.4722 - accuracy: 0.8327
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 32: val_loss did not improve from 0.83913
#
# Epoch 32: val_loss did not improve from 0.83913
#
# Epoch 32: saving model to models//keras/check_model_last.h5
#
# Epoch 32: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 3ms/step - loss: 0.4721 - accuracy: 0.8325 - val_loss: 0.9107 - val_accuracy: 0.7382 - lr: 0.0010
# Epoch 33/50
# 1488/1498 [============================>.] - ETA: 0s - loss: 0.4537 - accuracy: 0.8401
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 33: val_loss did not improve from 0.83913
#
# Epoch 33: val_loss did not improve from 0.83913
#
# Epoch 33: saving model to models//keras/check_model_last.h5
#
# Epoch 33: saving model to models//keras/check_model_last_weights.h5
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.4542 - accuracy: 0.8399 - val_loss: 1.0605 - val_accuracy: 0.7101 - lr: 0.0010
# Epoch 34/50
# 1477/1498 [============================>.] - ETA: 0s - loss: 0.3665 - accuracy: 0.8705
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 34: val_loss did not improve from 0.83913
#
# Epoch 34: val_loss did not improve from 0.83913
#
# Epoch 34: saving model to models//keras/check_model_last.h5
#
# Epoch 34: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.3662 - accuracy: 0.8707 - val_loss: 0.8538 - val_accuracy: 0.7598 - lr: 5.0000e-04
# Epoch 35/50
# 1489/1498 [============================>.] - ETA: 0s - loss: 0.3521 - accuracy: 0.8749
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 35: val_loss did not improve from 0.83913
#
# Epoch 35: val_loss did not improve from 0.83913
#
# Epoch 35: saving model to models//keras/check_model_last.h5
#
# Epoch 35: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.3523 - accuracy: 0.8749 - val_loss: 0.9385 - val_accuracy: 0.7448 - lr: 5.0000e-04
# Epoch 36/50
# 1482/1498 [============================>.] - ETA: 0s - loss: 0.3491 - accuracy: 0.8795
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 36: val_loss did not improve from 0.83913
#
# Epoch 36: val_loss did not improve from 0.83913
#
# Epoch 36: saving model to models//keras/check_model_last.h5
#
# Epoch 36: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.3483 - accuracy: 0.8796 - val_loss: 0.8798 - val_accuracy: 0.7654 - lr: 5.0000e-04
# Epoch 37/50
# 1497/1498 [============================>.] - ETA: 0s - loss: 0.3410 - accuracy: 0.8824
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 37: val_loss did not improve from 0.83913
#
# Epoch 37: val_loss did not improve from 0.83913
#
# Epoch 37: saving model to models//keras/check_model_last.h5
#
# Epoch 37: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.3408 - accuracy: 0.8825 - val_loss: 0.9091 - val_accuracy: 0.7596 - lr: 5.0000e-04
# Epoch 38/50
# 1488/1498 [============================>.] - ETA: 0s - loss: 0.3301 - accuracy: 0.8853
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 38: val_loss did not improve from 0.83913
#
# Epoch 38: val_loss did not improve from 0.83913
#
# Epoch 38: saving model to models//keras/check_model_last.h5
#
# Epoch 38: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.3311 - accuracy: 0.8849 - val_loss: 0.9642 - val_accuracy: 0.7546 - lr: 5.0000e-04
# Epoch 39/50
# 1484/1498 [============================>.] - ETA: 0s - loss: 0.3281 - accuracy: 0.8854
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 39: val_loss did not improve from 0.83913
#
# Epoch 39: val_loss did not improve from 0.83913
#
# Epoch 39: saving model to models//keras/check_model_last.h5
#
# Epoch 39: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.3278 - accuracy: 0.8855 - val_loss: 0.9275 - val_accuracy: 0.7618 - lr: 5.0000e-04
# Epoch 40/50
# 1486/1498 [============================>.] - ETA: 0s - loss: 0.3234 - accuracy: 0.8880
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 40: val_loss did not improve from 0.83913
#
# Epoch 40: val_loss did not improve from 0.83913
#
# Epoch 40: saving model to models//keras/check_model_last.h5
#
# Epoch 40: saving model to models//keras/check_model_last_weights.h5
#
# Epoch 40: saving model to models//keras/check_model_epoch40.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 4ms/step - loss: 0.3237 - accuracy: 0.8877 - val_loss: 0.9129 - val_accuracy: 0.7600 - lr: 5.0000e-04
# Epoch 41/50
# 1484/1498 [============================>.] - ETA: 0s - loss: 0.3124 - accuracy: 0.8889
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 41: val_loss did not improve from 0.83913
#
# Epoch 41: val_loss did not improve from 0.83913
#
# Epoch 41: saving model to models//keras/check_model_last.h5
#
# Epoch 41: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 3ms/step - loss: 0.3122 - accuracy: 0.8889 - val_loss: 0.9389 - val_accuracy: 0.7594 - lr: 5.0000e-04
# Epoch 42/50
# 1481/1498 [============================>.] - ETA: 0s - loss: 0.3116 - accuracy: 0.8918
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 42: val_loss did not improve from 0.83913
#
# Epoch 42: val_loss did not improve from 0.83913
#
# Epoch 42: saving model to models//keras/check_model_last.h5
#
# Epoch 42: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 3ms/step - loss: 0.3120 - accuracy: 0.8916 - val_loss: 0.9743 - val_accuracy: 0.7544 - lr: 5.0000e-04
# Epoch 43/50
# 1485/1498 [============================>.] - ETA: 0s - loss: 0.3012 - accuracy: 0.8962
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 43: val_loss did not improve from 0.83913
#
# Epoch 43: val_loss did not improve from 0.83913
#
# Epoch 43: saving model to models//keras/check_model_last.h5
#
# Epoch 43: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 4ms/step - loss: 0.3024 - accuracy: 0.8959 - val_loss: 1.0185 - val_accuracy: 0.7464 - lr: 5.0000e-04
# Epoch 44/50
# 1497/1498 [============================>.] - ETA: 0s - loss: 0.3012 - accuracy: 0.8961
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 44: val_loss did not improve from 0.83913
#
# Epoch 44: val_loss did not improve from 0.83913
#
# Epoch 44: saving model to models//keras/check_model_last.h5
#
# Epoch 44: saving model to models//keras/check_model_last_weights.h5
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 6s 4ms/step - loss: 0.3011 - accuracy: 0.8961 - val_loss: 0.9671 - val_accuracy: 0.7594 - lr: 5.0000e-04
# Epoch 45/50
# 1490/1498 [============================>.] - ETA: 0s - loss: 0.2543 - accuracy: 0.9152
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 45: val_loss did not improve from 0.83913
#
# Epoch 45: val_loss did not improve from 0.83913
#
# Epoch 45: saving model to models//keras/check_model_last.h5
#
# Epoch 45: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 4ms/step - loss: 0.2542 - accuracy: 0.9153 - val_loss: 0.9426 - val_accuracy: 0.7748 - lr: 2.5000e-04
# Epoch 46/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 0.2501 - accuracy: 0.9176
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 46: val_loss did not improve from 0.83913
#
# Epoch 46: val_loss did not improve from 0.83913
#
# Epoch 46: saving model to models//keras/check_model_last.h5
#
# Epoch 46: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 5s 4ms/step - loss: 0.2501 - accuracy: 0.9175 - val_loss: 0.9684 - val_accuracy: 0.7666 - lr: 2.5000e-04
# Epoch 47/50
# 1498/1498 [==============================] - ETA: 0s - loss: 0.2469 - accuracy: 0.9168
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 47: val_loss did not improve from 0.83913
#
# Epoch 47: val_loss did not improve from 0.83913
#
# Epoch 47: saving model to models//keras/check_model_last.h5
#
# Epoch 47: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 6s 4ms/step - loss: 0.2469 - accuracy: 0.9168 - val_loss: 0.9621 - val_accuracy: 0.7742 - lr: 2.5000e-04
# Epoch 48/50
# 1493/1498 [============================>.] - ETA: 0s - loss: 0.2454 - accuracy: 0.9173
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 48: val_loss did not improve from 0.83913
#
# Epoch 48: val_loss did not improve from 0.83913
#
# Epoch 48: saving model to models//keras/check_model_last.h5
#
# Epoch 48: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.2455 - accuracy: 0.9173 - val_loss: 0.9796 - val_accuracy: 0.7708 - lr: 2.5000e-04
# Epoch 49/50
# 1479/1498 [============================>.] - ETA: 0s - loss: 0.2409 - accuracy: 0.9208
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 49: val_loss did not improve from 0.83913
#
# Epoch 49: val_loss did not improve from 0.83913
#
# Epoch 49: saving model to models//keras/check_model_last.h5
#
# Epoch 49: saving model to models//keras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 2ms/step - loss: 0.2412 - accuracy: 0.9204 - val_loss: 0.9761 - val_accuracy: 0.7684 - lr: 2.5000e-04
# Epoch 50/50
# 1476/1498 [============================>.] - ETA: 0s - loss: 0.2367 - accuracy: 0.9220
# ***callbacks***
# saving losses to models//keras/losses.log
#
# Epoch 50: val_loss did not improve from 0.83913
#
# Epoch 50: val_loss did not improve from 0.83913
#
# Epoch 50: saving model to models//keras/check_model_last.h5
#
# Epoch 50: saving model to models//keras/check_model_last_weights.h5
#
# Epoch 50: saving model to models//keras/check_model_epoch50.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 4s 2ms/step - loss: 0.2360 - accuracy: 0.9221 - val_loss: 1.0125 - val_accuracy: 0.7698 - lr: 2.5000e-04

# %%
if KERAS_TRAIN:
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Test')
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Test')
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loc='upper left')
    plt.show()

# %%
import plotting
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

y_keras = model.predict(X_test)

print("Keras accuracy: {:.6f}%".format(100.0 * accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_keras, axis=1))))

#plt.figure(figsize=(9, 9))
#_ = plotting.makeRoc(y_test, y_keras, label_encoder.classes_)
# Out:
# 156/156 [==============================] - 0s 1ms/step
# Keras accuracy: 74.459135%

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

def plot_confusion_matrix(cm, class_names):
    """
    Plots a confusion matrix using seaborn's heatmap.
    
    Args:
        cm (array, shape = [n, n]): Confusion matrix
        class_names (array, shape = [n]): Array of class names
    """
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.title('Confusion Matrix')
    plt.show()

y_test_ = np.argmax(y_test, axis=1)
y_keras_ = np.argmax(y_keras, axis=1)

cm = confusion_matrix(y_test_, y_keras_)

plot_confusion_matrix(cm, classes)

# %% [markdown]
# ## Keras to hls4ml (Post Training Quantization)

# %%
# !mkdir -p projects

# %%
import hls4ml

config = hls4ml.utils.config_from_keras_model(model, granularity='name')
print("-----------------------------------")
print("Configuration")
plotting.print_dict(config)
print("-----------------------------------")
hls_model = hls4ml.converters.convert_from_keras_model(
    model, hls_config=config, output_dir='projects/ptq_hls4ml_prj', part='xcu250-figd2104-2L-e'
)
# Out:
# WARNING: Failed to import handlers from pooling.py: No module named 'torch'.
# WARNING: Failed to import handlers from convolution.py: No module named 'torch'.
# WARNING: Failed to import handlers from reshape.py: No module named 'torch'.
# WARNING: Failed to import handlers from merge.py: No module named 'torch'.
# WARNING: Failed to import handlers from core.py: No module named 'torch'.
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# -----------------------------------
# Configuration
# Model
#   Precision:         fixed<16,6>
#   ReuseFactor:       1
#   Strategy:          Latency
#   BramFactor:        1000000000
#   TraceOutput:       False
# LayerName
#   conv1_input
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   conv1
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#       weight:        fixed<16,6>
#       bias:          fixed<16,6>
#   conv1_relu
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   maxpool1
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   conv2
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#       weight:        fixed<16,6>
#       bias:          fixed<16,6>
#   conv2_relu
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   maxpool2
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   flatten
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   dense1
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#       weight:        fixed<16,6>
#       bias:          fixed<16,6>
#   dense1_relu
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   output
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#       weight:        fixed<16,6>
#       bias:          fixed<16,6>
#   output_softmax
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
# -----------------------------------
# Interpreting Sequential
# Topology:
# Layer name: conv1_input, layer type: InputLayer, input shapes: [[None, 64, 64, 3]], output shape: [None, 64, 64, 3]
# Layer name: conv1, layer type: Conv2D, input shapes: [[None, 64, 64, 3]], output shape: [None, 62, 62, 4]
# Layer name: maxpool1, layer type: MaxPooling2D, input shapes: [[None, 62, 62, 4]], output shape: [None, 31, 31, 4]
# Layer name: conv2, layer type: Conv2D, input shapes: [[None, 31, 31, 4]], output shape: [None, 29, 29, 8]
# Layer name: maxpool2, layer type: MaxPooling2D, input shapes: [[None, 29, 29, 8]], output shape: [None, 14, 14, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 14, 14, 8]], output shape: [None, 1568]
# Layer name: dense1, layer type: Dense, input shapes: [[None, 1568]], output shape: [None, 32]
# Layer name: output, layer type: Dense, input shapes: [[None, 32]], output shape: [None, 52]
# Creating HLS model
# WARNING: Layer conv1 requires "dataflow" pipeline style. Switching to "dataflow" pipeline style.
# /home/giuseppe/miniconda3/envs/pokerml-env/lib/python3.10/site-packages/hls4ml/converters/__init__.py:27: UserWarning: WARNING: Pytorch converter is not enabled!
#   warnings.warn("WARNING: Pytorch converter is not enabled!", stacklevel=1)

# %%
hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True, to_file=None)

# %% [markdown]
# The following cell takes approx. 5 minutes. It tries to compile the weights in the header files, while it should load them on the run. Not big issue, but annoying.

# %%
hls_model.compile()
X_test = np.ascontiguousarray(X_test)
y_hls = hls_model.predict(X_test)

print("Keras  accuracy: {}".format(100.*accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_keras, axis=1))))
print("hls4ml accuracy: {}".format(100.*accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_hls, axis=1))))
# Out:
# Writing HLS project
# Done
# Keras  accuracy: 74.45913461538461
# hls4ml accuracy: 0.9815705128205128

# %% [raw]
# fig, ax = plt.subplots(figsize=(9, 9))
# _ = plotting.makeRoc(y_test, y_keras, label_encoder.classes_)
# plt.gca().set_prop_cycle(None)  # reset the colors
# _ = plotting.makeRoc(y_test, y_hls, label_encoder.classes_, linestyle='--')
#
# from matplotlib.lines import Line2D
#
# lines = [Line2D([0], [0], ls='-'), Line2D([0], [0], ls='--')]
# from matplotlib.legend import Legend
#
# leg = Legend(ax, lines, labels=['keras', 'hls4ml'], loc='lower right', frameon=False)
# ax.add_artist(leg)

# %%
y_test_ = np.argmax(y_test, axis=1)
y_hls_ = np.argmax(y_hls, axis=1)

cm = confusion_matrix(y_test_, y_hls_)

plot_confusion_matrix(cm, classes)

# %% [markdown]
# ## QKeras

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
seed = 0
np.random.seed(seed)
import tensorflow as tf

tf.random.set_seed(seed)
import os

# %% [raw]
# X_train_val = np.load('X_train_val.npy')
# X_test = np.load('X_test.npy')
# y_train_val = np.load('y_train_val.npy')
# y_test = np.load('y_test.npy')
# classes = np.load('classes.npy', allow_pickle=True)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1
from callbacks import all_callbacks
from tensorflow.keras.layers import Activation
from qkeras import QDense, QActivation, QConv2D
from qkeras.quantizers import quantized_bits, quantized_relu

# %%
model = Sequential()
model.add(QConv2D(4,
                 (3, 3),
                 input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, 3),
                 kernel_quantizer=quantized_bits(6),
                 bias_quantizer=quantized_bits(6), 
                 name='conv1'))
model.add(QActivation(activation=quantized_relu(6),
                      name='relu1'))
model.add(MaxPooling2D(pool_size=(2, 2),
                       name='maxpool1'))
model.add(QConv2D(8,
                 (3, 3),
                 kernel_quantizer=quantized_bits(6),
                 bias_quantizer=quantized_bits(6), 
                 name='conv2'))
model.add(QActivation(activation=quantized_relu(6),
                      name='relu2'))
model.add(MaxPooling2D(pool_size=(2, 2),
                       name='maxpool2'))
model.add(Flatten(name='flatten'))
model.add(QDense(32,
                 kernel_quantizer=quantized_bits(6),
                 bias_quantizer=quantized_bits(6), 
                 name='dense1'))
model.add(QActivation(activation=quantized_relu(6),
                      name='relu3'))
model.add(QDense(NUM_CLASSES,
                 kernel_quantizer=quantized_bits(6),
                 bias_quantizer=quantized_bits(6), 
                 activation='softmax',
                 name='output'))
# Out:
# WARNING:tensorflow:From /home/giuseppe/miniconda3/envs/pokerml-env/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/giuseppe/miniconda3/envs/pokerml-env/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
if QKERAS_TRAIN:
    adam = Adam(lr=0.001)
    model.compile(optimizer=adam, loss=['categorical_crossentropy'], metrics=['accuracy'])
    callbacks = all_callbacks(
        stop_patience=1000,
        lr_factor=0.5,
        lr_patience=10,
        lr_epsilon=0.000001,
        lr_cooldown=2,
        lr_minimum=0.0000001,
        outputDir=MODELS_DIR + 'qkeras',
    )
    model.fit(
        X_train_val,
        y_train_val,
        batch_size=10,
        epochs=50,
        validation_split=0.25,
        shuffle=True,
        callbacks=callbacks.callbacks,
    )
    

else:
    from tensorflow.keras.models import load_model
    from qkeras.utils import _add_supported_quantized_objects

    co = {}
    _add_supported_quantized_objects(co)
    
    model = load_model(MODELS_DIR + 'qkeras/KERAS_check_best_model.h5')
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
#    1/1498 [..............................] - ETA: 39:22 - loss: 4.1462 - accuracy: 0.0000e+00WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0042s vs `on_train_batch_end` time: 0.0051s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0042s vs `on_train_batch_end` time: 0.0051s). Check your callbacks.
# 1497/1498 [============================>.] - ETA: 0s - loss: 3.7600 - accuracy: 0.0487
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 1: val_loss improved from inf to 3.51568, saving model to models/qkeras/check_best_model.h5
#
# Epoch 1: val_loss improved from inf to 3.51568, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 1: saving model to models/qkeras/check_model_last.h5
#
# Epoch 1: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 16s 10ms/step - loss: 3.7600 - accuracy: 0.0487 - val_loss: 3.5157 - val_accuracy: 0.0885 - lr: 0.0010
# Epoch 2/50
# 1491/1498 [============================>.] - ETA: 0s - loss: 3.3902 - accuracy: 0.1242
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 2: val_loss improved from 3.51568 to 3.23856, saving model to models/qkeras/check_best_model.h5
#
# Epoch 2: val_loss improved from 3.51568 to 3.23856, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 2: saving model to models/qkeras/check_model_last.h5
#
# Epoch 2: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 14s 9ms/step - loss: 3.3897 - accuracy: 0.1243 - val_loss: 3.2386 - val_accuracy: 0.1655 - lr: 0.0010
# Epoch 3/50
# 1498/1498 [==============================] - ETA: 0s - loss: 3.0312 - accuracy: 0.1874
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 3: val_loss improved from 3.23856 to 2.82341, saving model to models/qkeras/check_best_model.h5
#
# Epoch 3: val_loss improved from 3.23856 to 2.82341, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 3: saving model to models/qkeras/check_model_last.h5
#
# Epoch 3: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 14s 9ms/step - loss: 3.0312 - accuracy: 0.1874 - val_loss: 2.8234 - val_accuracy: 0.2294 - lr: 0.0010
# Epoch 4/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 2.6691 - accuracy: 0.2699
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 4: val_loss improved from 2.82341 to 2.45714, saving model to models/qkeras/check_best_model.h5
#
# Epoch 4: val_loss improved from 2.82341 to 2.45714, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 4: saving model to models/qkeras/check_model_last.h5
#
# Epoch 4: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 2.6685 - accuracy: 0.2699 - val_loss: 2.4571 - val_accuracy: 0.3411 - lr: 0.0010
# Epoch 5/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 2.3335 - accuracy: 0.3584
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 5: val_loss improved from 2.45714 to 2.18795, saving model to models/qkeras/check_best_model.h5
#
# Epoch 5: val_loss improved from 2.45714 to 2.18795, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 5: saving model to models/qkeras/check_model_last.h5
#
# Epoch 5: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 14s 9ms/step - loss: 2.3335 - accuracy: 0.3585 - val_loss: 2.1880 - val_accuracy: 0.4127 - lr: 0.0010
# Epoch 6/50
# 1495/1498 [============================>.] - ETA: 0s - loss: 2.0716 - accuracy: 0.4468
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 6: val_loss improved from 2.18795 to 2.01450, saving model to models/qkeras/check_best_model.h5
#
# Epoch 6: val_loss improved from 2.18795 to 2.01450, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 6: saving model to models/qkeras/check_model_last.h5
#
# Epoch 6: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 12s 8ms/step - loss: 2.0717 - accuracy: 0.4466 - val_loss: 2.0145 - val_accuracy: 0.4453 - lr: 0.0010
# Epoch 7/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 1.8895 - accuracy: 0.5078
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 7: val_loss improved from 2.01450 to 1.88142, saving model to models/qkeras/check_best_model.h5
#
# Epoch 7: val_loss improved from 2.01450 to 1.88142, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 7: saving model to models/qkeras/check_model_last.h5
#
# Epoch 7: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 1.8902 - accuracy: 0.5073 - val_loss: 1.8814 - val_accuracy: 0.5028 - lr: 0.0010
# Epoch 8/50
# 1493/1498 [============================>.] - ETA: 0s - loss: 1.7481 - accuracy: 0.5490
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 8: val_loss improved from 1.88142 to 1.77816, saving model to models/qkeras/check_best_model.h5
#
# Epoch 8: val_loss improved from 1.88142 to 1.77816, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 8: saving model to models/qkeras/check_model_last.h5
#
# Epoch 8: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 1.7482 - accuracy: 0.5489 - val_loss: 1.7782 - val_accuracy: 0.5343 - lr: 0.0010
# Epoch 9/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 1.6372 - accuracy: 0.5855
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 9: val_loss improved from 1.77816 to 1.67986, saving model to models/qkeras/check_best_model.h5
#
# Epoch 9: val_loss improved from 1.77816 to 1.67986, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 9: saving model to models/qkeras/check_model_last.h5
#
# Epoch 9: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 14s 9ms/step - loss: 1.6372 - accuracy: 0.5855 - val_loss: 1.6799 - val_accuracy: 0.5623 - lr: 0.0010
# Epoch 10/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 1.5622 - accuracy: 0.6109
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 10: val_loss improved from 1.67986 to 1.65865, saving model to models/qkeras/check_best_model.h5
#
# Epoch 10: val_loss improved from 1.67986 to 1.65865, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 10: saving model to models/qkeras/check_model_last.h5
#
# Epoch 10: saving model to models/qkeras/check_model_last_weights.h5
#
# Epoch 10: saving model to models/qkeras/check_model_epoch10.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 1.5623 - accuracy: 0.6109 - val_loss: 1.6586 - val_accuracy: 0.5689 - lr: 0.0010
# Epoch 11/50
# 1497/1498 [============================>.] - ETA: 0s - loss: 1.5142 - accuracy: 0.6265
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 11: val_loss improved from 1.65865 to 1.58837, saving model to models/qkeras/check_best_model.h5
#
# Epoch 11: val_loss improved from 1.65865 to 1.58837, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 11: saving model to models/qkeras/check_model_last.h5
#
# Epoch 11: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 1.5144 - accuracy: 0.6263 - val_loss: 1.5884 - val_accuracy: 0.5807 - lr: 0.0010
# Epoch 12/50
# 1489/1498 [============================>.] - ETA: 0s - loss: 1.4207 - accuracy: 0.6510
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 12: val_loss improved from 1.58837 to 1.58168, saving model to models/qkeras/check_best_model.h5
#
# Epoch 12: val_loss improved from 1.58837 to 1.58168, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 12: saving model to models/qkeras/check_model_last.h5
#
# Epoch 12: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 1.4209 - accuracy: 0.6508 - val_loss: 1.5817 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 13/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 1.3513 - accuracy: 0.6682
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 13: val_loss improved from 1.58168 to 1.47746, saving model to models/qkeras/check_best_model.h5
# Epoch 13: val_loss improved from 1.58168 to 1.47746, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 13: saving model to models/qkeras/check_model_last.h5
#
# Epoch 13: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 12s 8ms/step - loss: 1.3515 - accuracy: 0.6682 - val_loss: 1.4775 - val_accuracy: 0.6014 - lr: 0.0010
# Epoch 14/50
# 1495/1498 [============================>.] - ETA: 0s - loss: 1.2801 - accuracy: 0.6920
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 14: val_loss improved from 1.47746 to 1.41025, saving model to models/qkeras/check_best_model.h5
#
# Epoch 14: val_loss improved from 1.47746 to 1.41025, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 14: saving model to models/qkeras/check_model_last.h5
#
# Epoch 14: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 1.2801 - accuracy: 0.6920 - val_loss: 1.4103 - val_accuracy: 0.6242 - lr: 0.0010
# Epoch 15/50
# 1497/1498 [============================>.] - ETA: 0s - loss: 1.2002 - accuracy: 0.7174
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 15: val_loss improved from 1.41025 to 1.36651, saving model to models/qkeras/check_best_model.h5
#
# Epoch 15: val_loss improved from 1.41025 to 1.36651, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 15: saving model to models/qkeras/check_model_last.h5
#
# Epoch 15: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 1.2003 - accuracy: 0.7173 - val_loss: 1.3665 - val_accuracy: 0.6380 - lr: 0.0010
# Epoch 16/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 1.1439 - accuracy: 0.7378
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 16: val_loss improved from 1.36651 to 1.32232, saving model to models/qkeras/check_best_model.h5
#
# Epoch 16: val_loss improved from 1.36651 to 1.32232, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 16: saving model to models/qkeras/check_model_last.h5
#
# Epoch 16: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 1.1446 - accuracy: 0.7375 - val_loss: 1.3223 - val_accuracy: 0.6504 - lr: 0.0010
# Epoch 17/50
# 1495/1498 [============================>.] - ETA: 0s - loss: 1.0922 - accuracy: 0.7516
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 17: val_loss improved from 1.32232 to 1.30387, saving model to models/qkeras/check_best_model.h5
#
# Epoch 17: val_loss improved from 1.32232 to 1.30387, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 17: saving model to models/qkeras/check_model_last.h5
#
# Epoch 17: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 1.0919 - accuracy: 0.7516 - val_loss: 1.3039 - val_accuracy: 0.6494 - lr: 0.0010
# Epoch 18/50
# 1493/1498 [============================>.] - ETA: 0s - loss: 1.0497 - accuracy: 0.7647
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 18: val_loss improved from 1.30387 to 1.28425, saving model to models/qkeras/check_best_model.h5
#
# Epoch 18: val_loss improved from 1.30387 to 1.28425, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 18: saving model to models/qkeras/check_model_last.h5
#
# Epoch 18: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 12s 8ms/step - loss: 1.0492 - accuracy: 0.7651 - val_loss: 1.2842 - val_accuracy: 0.6581 - lr: 0.0010
# Epoch 19/50
# 1495/1498 [============================>.] - ETA: 0s - loss: 1.0111 - accuracy: 0.7740
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 19: val_loss improved from 1.28425 to 1.24303, saving model to models/qkeras/check_best_model.h5
#
# Epoch 19: val_loss improved from 1.28425 to 1.24303, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 19: saving model to models/qkeras/check_model_last.h5
#
# Epoch 19: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 1.0112 - accuracy: 0.7741 - val_loss: 1.2430 - val_accuracy: 0.6605 - lr: 0.0010
# Epoch 20/50
# 1489/1498 [============================>.] - ETA: 0s - loss: 0.9709 - accuracy: 0.7862
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 20: val_loss improved from 1.24303 to 1.21813, saving model to models/qkeras/check_best_model.h5
#
# Epoch 20: val_loss improved from 1.24303 to 1.21813, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 20: saving model to models/qkeras/check_model_last.h5
#
# Epoch 20: saving model to models/qkeras/check_model_last_weights.h5
#
# Epoch 20: saving model to models/qkeras/check_model_epoch20.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 12s 8ms/step - loss: 0.9713 - accuracy: 0.7861 - val_loss: 1.2181 - val_accuracy: 0.6753 - lr: 0.0010
# Epoch 21/50
# 1493/1498 [============================>.] - ETA: 0s - loss: 0.9346 - accuracy: 0.7979
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 21: val_loss did not improve from 1.21813
#
# Epoch 21: val_loss did not improve from 1.21813
#
# Epoch 21: saving model to models/qkeras/check_model_last.h5
#
# Epoch 21: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 11s 7ms/step - loss: 0.9346 - accuracy: 0.7979 - val_loss: 1.2184 - val_accuracy: 0.6659 - lr: 0.0010
# Epoch 22/50
# 1497/1498 [============================>.] - ETA: 0s - loss: 0.9151 - accuracy: 0.8033
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 22: val_loss improved from 1.21813 to 1.21483, saving model to models/qkeras/check_best_model.h5
#
# Epoch 22: val_loss improved from 1.21813 to 1.21483, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 22: saving model to models/qkeras/check_model_last.h5
#
# Epoch 22: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 12s 8ms/step - loss: 0.9151 - accuracy: 0.8033 - val_loss: 1.2148 - val_accuracy: 0.6641 - lr: 0.0010
# Epoch 23/50
# 1490/1498 [============================>.] - ETA: 0s - loss: 0.8897 - accuracy: 0.8115
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 23: val_loss improved from 1.21483 to 1.18763, saving model to models/qkeras/check_best_model.h5
#
# Epoch 23: val_loss improved from 1.21483 to 1.18763, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 23: saving model to models/qkeras/check_model_last.h5
#
# Epoch 23: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 12s 8ms/step - loss: 0.8904 - accuracy: 0.8109 - val_loss: 1.1876 - val_accuracy: 0.6755 - lr: 0.0010
# Epoch 24/50
# 1495/1498 [============================>.] - ETA: 0s - loss: 0.8709 - accuracy: 0.8193
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 24: val_loss did not improve from 1.18763
#
# Epoch 24: val_loss did not improve from 1.18763
#
# Epoch 24: saving model to models/qkeras/check_model_last.h5
#
# Epoch 24: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 14s 9ms/step - loss: 0.8707 - accuracy: 0.8192 - val_loss: 1.1918 - val_accuracy: 0.6831 - lr: 0.0010
# Epoch 25/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 0.8502 - accuracy: 0.8256
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 25: val_loss improved from 1.18763 to 1.16626, saving model to models/qkeras/check_best_model.h5
#
# Epoch 25: val_loss improved from 1.18763 to 1.16626, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 25: saving model to models/qkeras/check_model_last.h5
#
# Epoch 25: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 0.8505 - accuracy: 0.8255 - val_loss: 1.1663 - val_accuracy: 0.6835 - lr: 0.0010
# Epoch 26/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 0.8397 - accuracy: 0.8268
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 26: val_loss did not improve from 1.16626
#
# Epoch 26: val_loss did not improve from 1.16626
#
# Epoch 26: saving model to models/qkeras/check_model_last.h5
#
# Epoch 26: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 0.8396 - accuracy: 0.8268 - val_loss: 1.1936 - val_accuracy: 0.6797 - lr: 0.0010
# Epoch 27/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 0.8221 - accuracy: 0.8329
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 27: val_loss improved from 1.16626 to 1.16286, saving model to models/qkeras/check_best_model.h5
#
# Epoch 27: val_loss improved from 1.16626 to 1.16286, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 27: saving model to models/qkeras/check_model_last.h5
#
# Epoch 27: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 0.8223 - accuracy: 0.8327 - val_loss: 1.1629 - val_accuracy: 0.6815 - lr: 0.0010
# Epoch 28/50
# 1495/1498 [============================>.] - ETA: 0s - loss: 0.8016 - accuracy: 0.8433
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 28: val_loss did not improve from 1.16286
#
# Epoch 28: val_loss did not improve from 1.16286
#
# Epoch 28: saving model to models/qkeras/check_model_last.h5
#
# Epoch 28: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 0.8020 - accuracy: 0.8433 - val_loss: 1.1734 - val_accuracy: 0.6815 - lr: 0.0010
# Epoch 29/50
# 1498/1498 [==============================] - ETA: 0s - loss: 0.7906 - accuracy: 0.8462
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 29: val_loss did not improve from 1.16286
#
# Epoch 29: val_loss did not improve from 1.16286
#
# Epoch 29: saving model to models/qkeras/check_model_last.h5
#
# Epoch 29: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 0.7906 - accuracy: 0.8462 - val_loss: 1.1741 - val_accuracy: 0.6787 - lr: 0.0010
# Epoch 30/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 0.7765 - accuracy: 0.8493
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 30: val_loss did not improve from 1.16286
#
# Epoch 30: val_loss did not improve from 1.16286
#
# Epoch 30: saving model to models/qkeras/check_model_last.h5
#
# Epoch 30: saving model to models/qkeras/check_model_last_weights.h5
#
# Epoch 30: saving model to models/qkeras/check_model_epoch30.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 0.7767 - accuracy: 0.8492 - val_loss: 1.1731 - val_accuracy: 0.6797 - lr: 0.0010
# Epoch 31/50
# 1498/1498 [==============================] - ETA: 0s - loss: 0.7634 - accuracy: 0.8543
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 31: val_loss improved from 1.16286 to 1.16192, saving model to models/qkeras/check_best_model.h5
#
# Epoch 31: val_loss improved from 1.16286 to 1.16192, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 31: saving model to models/qkeras/check_model_last.h5
#
# Epoch 31: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 0.7634 - accuracy: 0.8543 - val_loss: 1.1619 - val_accuracy: 0.6865 - lr: 0.0010
# Epoch 32/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 0.7454 - accuracy: 0.8592
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 32: val_loss did not improve from 1.16192
#
# Epoch 32: val_loss did not improve from 1.16192
#
# Epoch 32: saving model to models/qkeras/check_model_last.h5
#
# Epoch 32: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 0.7454 - accuracy: 0.8590 - val_loss: 1.1630 - val_accuracy: 0.6809 - lr: 0.0010
# Epoch 33/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 0.7406 - accuracy: 0.8591
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 33: val_loss improved from 1.16192 to 1.16182, saving model to models/qkeras/check_best_model.h5
#
# Epoch 33: val_loss improved from 1.16192 to 1.16182, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 33: saving model to models/qkeras/check_model_last.h5
#
# Epoch 33: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 0.7406 - accuracy: 0.8592 - val_loss: 1.1618 - val_accuracy: 0.6805 - lr: 0.0010
# Epoch 34/50
# 1498/1498 [==============================] - ETA: 0s - loss: 0.7327 - accuracy: 0.8610
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 34: val_loss improved from 1.16182 to 1.14896, saving model to models/qkeras/check_best_model.h5
#
# Epoch 34: val_loss improved from 1.16182 to 1.14896, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 34: saving model to models/qkeras/check_model_last.h5
#
# Epoch 34: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 0.7327 - accuracy: 0.8610 - val_loss: 1.1490 - val_accuracy: 0.6871 - lr: 0.0010
# Epoch 35/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 0.7173 - accuracy: 0.8698
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 35: val_loss did not improve from 1.14896
#
# Epoch 35: val_loss did not improve from 1.14896
#
# Epoch 35: saving model to models/qkeras/check_model_last.h5
#
# Epoch 35: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 14s 9ms/step - loss: 0.7174 - accuracy: 0.8699 - val_loss: 1.1914 - val_accuracy: 0.6709 - lr: 0.0010
# Epoch 36/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 0.7061 - accuracy: 0.8675
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 36: val_loss did not improve from 1.14896
#
# Epoch 36: val_loss did not improve from 1.14896
#
# Epoch 36: saving model to models/qkeras/check_model_last.h5
#
# Epoch 36: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 14s 9ms/step - loss: 0.7061 - accuracy: 0.8675 - val_loss: 1.1657 - val_accuracy: 0.6783 - lr: 0.0010
# Epoch 37/50
# 1492/1498 [============================>.] - ETA: 0s - loss: 0.7018 - accuracy: 0.8739
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 37: val_loss did not improve from 1.14896
#
# Epoch 37: val_loss did not improve from 1.14896
#
# Epoch 37: saving model to models/qkeras/check_model_last.h5
#
# Epoch 37: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 8ms/step - loss: 0.7020 - accuracy: 0.8734 - val_loss: 1.1573 - val_accuracy: 0.6777 - lr: 0.0010
# Epoch 38/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 0.6949 - accuracy: 0.8760
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 38: val_loss improved from 1.14896 to 1.14744, saving model to models/qkeras/check_best_model.h5
#
# Epoch 38: val_loss improved from 1.14896 to 1.14744, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 38: saving model to models/qkeras/check_model_last.h5
#
# Epoch 38: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 14s 9ms/step - loss: 0.6951 - accuracy: 0.8757 - val_loss: 1.1474 - val_accuracy: 0.6821 - lr: 0.0010
# Epoch 39/50
# 1498/1498 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.8751
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 39: val_loss did not improve from 1.14744
#
# Epoch 39: val_loss did not improve from 1.14744
#
# Epoch 39: saving model to models/qkeras/check_model_last.h5
#
# Epoch 39: saving model to models/qkeras/check_model_last_weights.h5
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 0.6924 - accuracy: 0.8751 - val_loss: 1.1489 - val_accuracy: 0.6863 - lr: 0.0010
# Epoch 40/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 0.6869 - accuracy: 0.8779
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 40: val_loss improved from 1.14744 to 1.13829, saving model to models/qkeras/check_best_model.h5
#
# Epoch 40: val_loss improved from 1.14744 to 1.13829, saving model to models/qkeras/check_best_model_weights.h5
#
# Epoch 40: saving model to models/qkeras/check_model_last.h5
#
# Epoch 40: saving model to models/qkeras/check_model_last_weights.h5
#
# Epoch 40: saving model to models/qkeras/check_model_epoch40.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 0.6871 - accuracy: 0.8778 - val_loss: 1.1383 - val_accuracy: 0.6841 - lr: 0.0010
# Epoch 41/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 0.6822 - accuracy: 0.8761
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 41: val_loss did not improve from 1.13829
#
# Epoch 41: val_loss did not improve from 1.13829
#
# Epoch 41: saving model to models/qkeras/check_model_last.h5
#
# Epoch 41: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 13s 9ms/step - loss: 0.6821 - accuracy: 0.8760 - val_loss: 1.1708 - val_accuracy: 0.6723 - lr: 0.0010
# Epoch 42/50
# 1494/1498 [============================>.] - ETA: 0s - loss: 0.6767 - accuracy: 0.8796
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 42: val_loss did not improve from 1.13829
#
# Epoch 42: val_loss did not improve from 1.13829
#
# Epoch 42: saving model to models/qkeras/check_model_last.h5
#
# Epoch 42: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 10s 7ms/step - loss: 0.6767 - accuracy: 0.8797 - val_loss: 1.1437 - val_accuracy: 0.6847 - lr: 0.0010
# Epoch 43/50
# 1496/1498 [============================>.] - ETA: 0s - loss: 0.6736 - accuracy: 0.8811
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 43: val_loss did not improve from 1.13829
#
# Epoch 43: val_loss did not improve from 1.13829
#
# Epoch 43: saving model to models/qkeras/check_model_last.h5
#
# Epoch 43: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 8s 5ms/step - loss: 0.6735 - accuracy: 0.8812 - val_loss: 1.1647 - val_accuracy: 0.6725 - lr: 0.0010
# Epoch 44/50
# 1498/1498 [==============================] - ETA: 0s - loss: 0.6717 - accuracy: 0.8796
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 44: val_loss did not improve from 1.13829
#
# Epoch 44: val_loss did not improve from 1.13829
#
# Epoch 44: saving model to models/qkeras/check_model_last.h5
#
# Epoch 44: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 8s 5ms/step - loss: 0.6717 - accuracy: 0.8796 - val_loss: 1.1485 - val_accuracy: 0.6779 - lr: 0.0010
# Epoch 45/50
# 1492/1498 [============================>.] - ETA: 0s - loss: 0.6667 - accuracy: 0.8814
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 45: val_loss did not improve from 1.13829
#
# Epoch 45: val_loss did not improve from 1.13829
#
# Epoch 45: saving model to models/qkeras/check_model_last.h5
#
# Epoch 45: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 8s 5ms/step - loss: 0.6670 - accuracy: 0.8813 - val_loss: 1.1506 - val_accuracy: 0.6793 - lr: 0.0010
# Epoch 46/50
# 1492/1498 [============================>.] - ETA: 0s - loss: 0.6642 - accuracy: 0.8822
# ***callbacks***
# saving losses to models/qkeras/losses.log
#
# Epoch 46: val_loss did not improve from 1.13829
#
# Epoch 46: val_loss did not improve from 1.13829
#
# Epoch 46: saving model to models/qkeras/check_model_last.h5
#
# Epoch 46: saving model to models/qkeras/check_model_last_weights.h5
#
# ***callbacks end***
#
# 1498/1498 [==============================] - 7s 5ms/step - loss: 0.6639 - accuracy: 0.8823 - val_loss: 1.1490 - val_accuracy: 0.6843 - lr: 0.0010
# Epoch 47/50
#   26/1498 [..............................] - ETA: 6s - loss: 0.6478 - accuracy: 0.9115

# %%
y_qkeras = model.predict(np.ascontiguousarray(X_test))

print("QKeras accuracy: {:.6f}%".format(100.*accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_qkeras, axis=1))))

# %% [markdown]
# ## QKeras to hls4ml (Quantization Aware Training)

# %% [markdown]
# The following cell takes approx. 5 minutes. It tries to compile the weights in the header files, while it should load them on the run. Not big issue, but annoying.

# %%
import hls4ml
import plotting

config = hls4ml.utils.config_from_keras_model(model, granularity='name')
config['LayerName']['output']['exp_table_t'] = 'ap_fixed<18,8>'
config['LayerName']['output']['inv_table_t'] = 'ap_fixed<18,4>'
print("-----------------------------------")
plotting.print_dict(config)
print("-----------------------------------")
hls_model = hls4ml.converters.convert_from_keras_model(
    model, hls_config=config, output_dir='model_2/hls4ml_prj', part='xcu250-figd2104-2L-e'
)
hls_model.compile()

# %%
y_qkeras = model.predict(np.ascontiguousarray(X_test))
y_hls = hls_model.predict(np.ascontiguousarray(X_test))
#np.save('model_2/y_qkeras.npy', y_qkeras)
#np.save('model_2/y_hls.npy', y_hls)

# %%
# %matplotlib inline
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model

#model_ref = load_model('model_1/KERAS_check_best_model.h5')
#y_ref = model_ref.predict(X_test)

print("Accuracy baseline:  {:.6f}%".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_keras, axis=1))))
print("Accuracy quantized: {:.6f}%".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_qkeras, axis=1))))
print("Accuracy hls4ml:    {:.6f}%".format(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_hls, axis=1))))

# %%
# fig, ax = plt.subplots(figsize=(9, 9))
# _ = plotting.makeRoc(y_test, y_ref, classes)
# plt.gca().set_prop_cycle(None)  # reset the colors
# _ = plotting.makeRoc(y_test, y_qkeras, classes, linestyle='--')
# plt.gca().set_prop_cycle(None)  # reset the colors
# _ = plotting.makeRoc(y_test, y_hls, classes, linestyle=':')

# from matplotlib.lines import Line2D

# lines = [Line2D([0], [0], ls='-'), Line2D([0], [0], ls='--'), Line2D([0], [0], ls=':')]
# from matplotlib.legend import Legend

# leg = Legend(ax, lines, labels=['baseline', 'quantized', 'hls4ml'], loc='lower right', frameon=False)
# ax.add_artist(leg)

# %%
y_test_ = np.argmax(y_test, axis=1)
y_qkeras_ = np.argmax(y_qkeras, axis=1)

cm = confusion_matrix(y_test_, y_qkeras_)

plot_confusion_matrix(cm, classes)
